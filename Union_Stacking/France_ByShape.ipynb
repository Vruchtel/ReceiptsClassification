# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import os
import skimage
import math
from skimage.io import imsave, imread
from skimage.transform import resize
from PIL import Image
from shutil import copyfile
from collections import Counter
from sklearn.metrics import confusion_matrix
import itertools

import keras
from keras.models import Sequential
from keras.layers import Dense, Activation, Flatten, Dropout
from keras.optimizers import SGD, Adadelta, Adam
from keras.applications.xception import Xception
from keras.applications.vgg16 import VGG16

from keras.layers import BatchNormalization
from keras.optimizers import RMSprop

from keras.utils import np_utils

from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score
from sklearn import neighbors
from sklearn.svm import SVC

# %matplotlib inline
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
import tensorflow as tf
os.environ["CUDA_VISIBLE_DEVICES"] = '0' #use GPU with ID=0
config = tf.ConfigProto()
config.gpu_options.per_process_gpu_memory_fraction = 0.5 # maximun alloc gpu50% of MEM
config.gpu_options.allow_growth = True #allocate dynamically
sess = tf.Session(config = config)

# %%
from preprocess import one_hot
from confusion_matrix import print_confusion_matrix

# %%
CATEGORIES_COUNT = 3

# %%
VGG16_and_meta_results_path = "D:/svruchtel/PREPROCESSED_DATA/after_VGG16_5_parts/"
texts_stacking_results_path = "C:/Users/svruchtel/Documents/1/Texts classification/stacking_just_for_texts/Stacking_Results_France_ByShape/"

# %%
y_train = np.load("D:/svruchtel/PREPROCESSED_DATA/LSTM_results_word_emb/France_ByShape_1st_net_train_y.npy").argmax(axis=1)
y_test = np.load("D:/svruchtel/PREPROCESSED_DATA/LSTM_results_word_emb/France_ByShape_1st_net_test_y.npy").argmax(axis=1)

# %%
print(y_train.shape)
print(y_test.shape)
# Out:
# (3234,)
# (362,)

# %%
#images_train_knn_distance = np.load(VGG16_and_meta_results_path + "knn_distance_15_train_France_ByShape128.npy").argmax(axis=1)
#images_test_knn_distance = np.load(VGG16_and_meta_results_path + "knn_distance_15_test_France_ByShape128.npy").argmax(axis=1)

#images_train_svm = np.load(VGG16_and_meta_results_path + "svm_train_France_ByShape128.npy")
#images_test_svm = np.load(VGG16_and_meta_results_path + "svm_test_France_ByShape128.npy")

texts_train_net_2_3 = np.load(texts_stacking_results_path + "meta_net_train_2_3_GLOVE_FR.npy")
texts_test_net_2_3 = np.load(texts_stacking_results_path + "meta_net_test_2_3_GLOVE_FR.npy")

texts_train_net_3_3 = np.load(texts_stacking_results_path + "meta_net_train_3_3_GLOVE_FR.npy")
texts_test_net_3_3 = np.load(texts_stacking_results_path + "meta_net_test_3_3_GLOVE_FR.npy")

texts_train_net_2_4 = np.load(texts_stacking_results_path + "meta_net_train_2_4_GLOVE_FR.npy")
texts_test_net_2_4 = np.load(texts_stacking_results_path + "meta_net_test_2_4_GLOVE_FR.npy")

# %%
after_VGG16_un_train = np.load(VGG16_and_meta_results_path + "un_train_France_ByShape128.npy")
after_VGG16_un_test = np.load(VGG16_and_meta_results_path + "un_test_France_ByShape128.npy")

# %%
knn_distance_15 = neighbors.KNeighborsClassifier(n_neighbors=15, weights='distance')
knn_distance_15.fit(after_VGG16_un_train, one_hot(y_train, CATEGORIES_COUNT))

acc_knn_distance_15 = accuracy_score(one_hot(y_test, CATEGORIES_COUNT), knn_distance_15.predict(after_VGG16_un_test))
print("test accuracy:  %.4f" % acc_knn_distance_15)
print("")

images_train_knn_distance = knn_distance_15.predict(after_VGG16_un_train).argmax(axis=1)
images_test_knn_distance = knn_distance_15.predict(after_VGG16_un_test).argmax(axis=1)
# Out:
# test accuracy:  0.9337

# %%
svm = SVC(kernel='rbf')
svm.fit(after_VGG16_un_train, y_train)

acc_svm = accuracy_score(y_test, svm.predict(after_VGG16_un_test))
print("test accuracy:  %.4f" % acc_svm)
print("")

images_train_svm = svm.predict(after_VGG16_un_train)
images_test_svm = svm.predict(after_VGG16_un_test)
# Out:
# test accuracy:  0.9282

# %%
images_train_knn_distance = images_train_knn_distance.reshape((images_train_knn_distance.shape[0], 1))
images_test_knn_distance = images_test_knn_distance.reshape((images_test_knn_distance.shape[0], 1))

images_train_svm = images_train_svm.reshape((images_train_svm.shape[0], 1))
images_test_svm = images_test_svm.reshape((images_test_svm.shape[0], 1))

texts_train_net_2_3 = texts_train_net_2_3.reshape((texts_train_net_2_3.shape[0], 1))
texts_test_net_2_3 = texts_test_net_2_3.reshape((texts_test_net_2_3.shape[0], 1))

texts_train_net_3_3 = texts_train_net_3_3.reshape((texts_train_net_3_3.shape[0], 1))
texts_test_net_3_3 = texts_test_net_3_3.reshape((texts_test_net_3_3.shape[0], 1))

texts_train_net_2_4 = texts_train_net_2_4.reshape((texts_train_net_2_4.shape[0], 1))
texts_test_net_2_4 = texts_test_net_2_4.reshape((texts_test_net_2_4.shape[0], 1))

# %%
texts_train_net_3_3.shape
# Out:
# (3234, 1)

# %%
def run_knn_uniform(X_train, X_test):
    knn_uniform_15 = neighbors.KNeighborsClassifier(n_neighbors=15, weights='uniform')
    knn_uniform_15.fit(X_train, y_train)

    acc_knn_uniform_15 = accuracy_score(y_test, knn_uniform_15.predict(X_test))
    print("test accuracy:  %.4f" % acc_knn_uniform_15)
    print("")

    y_train_pred = knn_uniform_15.predict(X_train)
    y_test_pred = knn_uniform_15.predict(X_test)

    print("TRAIN CONFUSION MATRIX")
    print_confusion_matrix(X_train, y_train, y_train_pred, categories_count=CATEGORIES_COUNT)

    print("")
    print("TEST CONFUSION MATRIX")
    print_confusion_matrix(X_test, y_test, y_test_pred, categories_count=CATEGORIES_COUNT)

# %%
def run_knn_distance(X_train, X_test):
    knn_distance_15 = neighbors.KNeighborsClassifier(n_neighbors=15, weights='distance')
    knn_distance_15.fit(X_train, y_train)

    acc_knn_distance_15 = accuracy_score(y_test, knn_distance_15.predict(X_test))
    print("test accuracy:  %.4f" % acc_knn_distance_15)
    print("")

    y_train_pred = knn_distance_15.predict(X_train)
    y_test_pred = knn_distance_15.predict(X_test)

    print("TRAIN CONFUSION MATRIX")
    print_confusion_matrix(X_train, y_train, y_train_pred, categories_count=CATEGORIES_COUNT)

    print("")
    print("TEST CONFUSION MATRIX")
    print_confusion_matrix(X_test, y_test, y_test_pred, categories_count=CATEGORIES_COUNT)

# %%
def run_svm(X_train, X_test):
    svm = SVC(kernel='rbf')
    svm.fit(X_train, y_train)

    acc_svm = accuracy_score(y_test, svm.predict(X_test))
    print("test accuracy:  %.4f" % acc_svm)
    print("")

    y_train_pred = svm.predict(X_train)
    y_test_pred = svm.predict(X_test)

    print("TRAIN CONFUSION MATRIX")
    print_confusion_matrix(X_train, y_train, y_train_pred, categories_count=CATEGORIES_COUNT)

    print("")
    print("TEST CONFUSION MATRIX")
    print_confusion_matrix(X_test, y_test, y_test_pred, categories_count=CATEGORIES_COUNT)

# %%
def run_meta_net(X_train, X_test):
    
    categories_count = CATEGORIES_COUNT

    meta_net = Sequential()
    meta_net.add(Dense(512, input_shape=X_train[0].shape))
    meta_net.add(Dropout(0.5))
    meta_net.add(Dense(256))
    meta_net.add(Dropout(0.5))
    meta_net.add(Dense(categories_count, activation='softmax'))
    meta_net.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    print(meta_net.summary())
    
    callback = keras.callbacks.EarlyStopping(monitor='val_loss', min_delta=0, patience=7, verbose=0, mode='auto')
    history_callback = meta_net.fit(X_train, one_hot(y_train, categories_count), 
                                validation_data=(X_test, one_hot(y_test, categories_count)), 
                                epochs=300, batch_size=100, callbacks=[callback])

    test_scores = meta_net.evaluate(X_test, one_hot(y_test, CATEGORIES_COUNT), verbose=0)
    
    print("test accuracy:  %.4f" % test_scores[1])
    print("")

    y_train_pred = (meta_net.predict(X_train).round()).argmax(axis=1)
    y_test_pred = (meta_net.predict(X_test).round()).argmax(axis=1)

    print("TRAIN CONFUSION MATRIX")
    print_confusion_matrix(X_train, y_train, y_train_pred, categories_count=CATEGORIES_COUNT)

    print("")
    print("TEST CONFUSION MATRIX")
    print_confusion_matrix(X_test, y_test, y_test_pred, categories_count=CATEGORIES_COUNT)

# %% [markdown]
# ### images - knn, texts - 2_3

# %%
X_train = np.concatenate((images_train_knn_distance, texts_train_net_2_3), axis=1)
X_test = np.concatenate((images_test_knn_distance, texts_test_net_2_3), axis=1)

# %% [markdown]
# #### knn_uniform

# %%
run_knn_uniform(X_train, X_test)
# Out:
# test accuracy:  0.9337
#
# TRAIN CONFUSION MATRIX
# Confusion matrix, without normalization
# [[ 314    1    0]
#  [   0 2637    0]
#  [   0   11  271]]
# Normalized confusion matrix
# [[0.9968254  0.0031746  0.        ]
#  [0.         1.         0.        ]
#  [0.         0.03900709 0.96099291]]
# TEST CONFUSION MATRIX
# Confusion matrix, without normalization
# [[ 29   7   0]
#  [  6 288   0]
#  [  4   7  21]]
# Normalized confusion matrix
# [[0.80555556 0.19444444 0.        ]
#  [0.02040816 0.97959184 0.        ]
#  [0.125      0.21875    0.65625   ]]

# %% [markdown]
# #### knn_distance

# %%
run_knn_distance(X_train, X_test)
# Out:
# test accuracy:  0.9337
#
# TRAIN CONFUSION MATRIX
# Confusion matrix, without normalization
# [[ 314    1    0]
#  [   0 2637    0]
#  [   0    6  276]]
# Normalized confusion matrix
# [[0.9968254 0.0031746 0.       ]
#  [0.        1.        0.       ]
#  [0.        0.0212766 0.9787234]]
# TEST CONFUSION MATRIX
# Confusion matrix, without normalization
# [[ 29   5   2]
#  [  6 288   0]
#  [  4   7  21]]
# Normalized confusion matrix
# [[0.80555556 0.13888889 0.05555556]
#  [0.02040816 0.97959184 0.        ]
#  [0.125      0.21875    0.65625   ]]

# %% [markdown]
# #### svm

# %%
run_svm(X_train, X_test)
# Out:
# test accuracy:  0.9337
#
# TRAIN CONFUSION MATRIX
# Confusion matrix, without normalization
# [[ 314    1    0]
#  [   0 2637    0]
#  [   0    6  276]]
# Normalized confusion matrix
# [[0.9968254 0.0031746 0.       ]
#  [0.        1.        0.       ]
#  [0.        0.0212766 0.9787234]]
# TEST CONFUSION MATRIX
# Confusion matrix, without normalization
# [[ 29   5   2]
#  [  6 288   0]
#  [  4   7  21]]
# Normalized confusion matrix
# [[0.80555556 0.13888889 0.05555556]
#  [0.02040816 0.97959184 0.        ]
#  [0.125      0.21875    0.65625   ]]

# %% [markdown]
# #### meta_net

# %%
run_meta_net(X_train, X_test)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 512)               1536
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               131328
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 3)                 771
# =================================================================
# Total params: 133,635
# Trainable params: 133,635
# Non-trainable params: 0
# _________________________________________________________________
# None
# Train on 3234 samples, validate on 362 samples
# Epoch 1/300
# 3234/3234 [==============================] - 2s 586us/step - loss: 0.5237 - acc: 0.8485 - val_loss: 0.5400 - val_acc: 0.8757
# Epoch 2/300
# 3234/3234 [==============================] - 1s 188us/step - loss: 0.2224 - acc: 0.9456 - val_loss: 0.4942 - val_acc: 0.9337
# Epoch 3/300
# 3234/3234 [==============================] - 1s 189us/step - loss: 0.0440 - acc: 0.9963 - val_loss: 0.5310 - val_acc: 0.9337
# Epoch 4/300
# 3234/3234 [==============================] - 1s 183us/step - loss: 0.0215 - acc: 0.9978 - val_loss: 0.5385 - val_acc: 0.9337
# Epoch 5/300
# 3234/3234 [==============================] - 1s 190us/step - loss: 0.0204 - acc: 0.9975 - val_loss: 0.5477 - val_acc: 0.9337
# Epoch 6/300
# 3234/3234 [==============================] - 1s 189us/step - loss: 0.0165 - acc: 0.9978 - val_loss: 0.5515 - val_acc: 0.9337
# Epoch 7/300
# 3234/3234 [==============================] - 1s 188us/step - loss: 0.0129 - acc: 0.9978 - val_loss: 0.5750 - val_acc: 0.9337
# Epoch 8/300
# 3234/3234 [==============================] - 1s 195us/step - loss: 0.0168 - acc: 0.9975 - val_loss: 0.5560 - val_acc: 0.9337
# Epoch 9/300
# 3234/3234 [==============================] - 1s 185us/step - loss: 0.0145 - acc: 0.9978 - val_loss: 0.5795 - val_acc: 0.9337
# test accuracy:  0.9337
#
# TRAIN CONFUSION MATRIX
# Confusion matrix, without normalization
# [[ 314    1    0]
#  [   0 2637    0]
#  [   0    6  276]]
# Normalized confusion matrix
# [[0.9968254 0.0031746 0.       ]
#  [0.        1.        0.       ]
#  [0.        0.0212766 0.9787234]]
# TEST CONFUSION MATRIX
# Confusion matrix, without normalization
# [[ 29   5   2]
#  [  6 288   0]
#  [  4   7  21]]
# Normalized confusion matrix
# [[0.80555556 0.13888889 0.05555556]
#  [0.02040816 0.97959184 0.        ]
#  [0.125      0.21875    0.65625   ]]

# %% [markdown]
# ### images - knn, texts - 3_3

# %%
X_train = np.concatenate((images_train_knn_distance, texts_train_net_3_3), axis=1)
X_test = np.concatenate((images_test_knn_distance, texts_test_net_3_3), axis=1)

# %%
run_knn_uniform(X_train, X_test)
# Out:
# test accuracy:  0.9309
#
# TRAIN CONFUSION MATRIX
# Confusion matrix, without normalization
# [[ 314    1    0]
#  [   0 2637    0]
#  [   0   11  271]]
# Normalized confusion matrix
# [[0.9968254  0.0031746  0.        ]
#  [0.         1.         0.        ]
#  [0.         0.03900709 0.96099291]]
# TEST CONFUSION MATRIX
# Confusion matrix, without normalization
# [[ 29   7   0]
#  [  6 288   0]
#  [  4   8  20]]
# Normalized confusion matrix
# [[0.80555556 0.19444444 0.        ]
#  [0.02040816 0.97959184 0.        ]
#  [0.125      0.25       0.625     ]]

# %%
run_knn_distance(X_train, X_test)
# Out:
# test accuracy:  0.9337
#
# TRAIN CONFUSION MATRIX
# Confusion matrix, without normalization
# [[ 314    1    0]
#  [   0 2637    0]
#  [   0    6  276]]
# Normalized confusion matrix
# [[0.9968254 0.0031746 0.       ]
#  [0.        1.        0.       ]
#  [0.        0.0212766 0.9787234]]
# TEST CONFUSION MATRIX
# Confusion matrix, without normalization
# [[ 29   5   2]
#  [  6 288   0]
#  [  4   7  21]]
# Normalized confusion matrix
# [[0.80555556 0.13888889 0.05555556]
#  [0.02040816 0.97959184 0.        ]
#  [0.125      0.21875    0.65625   ]]

# %%
run_svm(X_train, X_test)
# Out:
# test accuracy:  0.9337
#
# TRAIN CONFUSION MATRIX
# Confusion matrix, without normalization
# [[ 314    1    0]
#  [   0 2637    0]
#  [   0    6  276]]
# Normalized confusion matrix
# [[0.9968254 0.0031746 0.       ]
#  [0.        1.        0.       ]
#  [0.        0.0212766 0.9787234]]
# TEST CONFUSION MATRIX
# Confusion matrix, without normalization
# [[ 29   5   2]
#  [  6 288   0]
#  [  4   7  21]]
# Normalized confusion matrix
# [[0.80555556 0.13888889 0.05555556]
#  [0.02040816 0.97959184 0.        ]
#  [0.125      0.21875    0.65625   ]]

# %%
run_meta_net(X_train, X_test)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_4 (Dense)              (None, 512)               1536
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 256)               131328
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_6 (Dense)              (None, 3)                 771
# =================================================================
# Total params: 133,635
# Trainable params: 133,635
# Non-trainable params: 0
# _________________________________________________________________
# None
# Train on 3234 samples, validate on 362 samples
# Epoch 1/300
# 3234/3234 [==============================] - 1s 447us/step - loss: 0.5596 - acc: 0.8336 - val_loss: 0.5005 - val_acc: 0.8785
# Epoch 2/300
# 3234/3234 [==============================] - 1s 188us/step - loss: 0.2341 - acc: 0.9493 - val_loss: 0.4640 - val_acc: 0.9337
# Epoch 3/300
# 3234/3234 [==============================] - 1s 185us/step - loss: 0.0516 - acc: 0.9951 - val_loss: 0.5078 - val_acc: 0.9337
# Epoch 4/300
# 3234/3234 [==============================] - 1s 191us/step - loss: 0.0237 - acc: 0.9978 - val_loss: 0.5372 - val_acc: 0.9337
# Epoch 5/300
# 3234/3234 [==============================] - 1s 188us/step - loss: 0.0188 - acc: 0.9975 - val_loss: 0.5568 - val_acc: 0.9337
# Epoch 6/300
# 3234/3234 [==============================] - 1s 189us/step - loss: 0.0188 - acc: 0.9978 - val_loss: 0.5601 - val_acc: 0.9337
# Epoch 7/300
# 3234/3234 [==============================] - 1s 185us/step - loss: 0.0177 - acc: 0.9978 - val_loss: 0.5655 - val_acc: 0.9337
# Epoch 8/300
# 3234/3234 [==============================] - 1s 187us/step - loss: 0.0162 - acc: 0.9978 - val_loss: 0.5617 - val_acc: 0.9337
# Epoch 9/300
# 3234/3234 [==============================] - 1s 185us/step - loss: 0.0177 - acc: 0.9978 - val_loss: 0.5617 - val_acc: 0.9337
# test accuracy:  0.9337
#
# TRAIN CONFUSION MATRIX
# Confusion matrix, without normalization
# [[ 314    1    0]
#  [   0 2637    0]
#  [   0    6  276]]
# Normalized confusion matrix
# [[0.9968254 0.0031746 0.       ]
#  [0.        1.        0.       ]
#  [0.        0.0212766 0.9787234]]
# TEST CONFUSION MATRIX
# Confusion matrix, without normalization
# [[ 29   5   2]
#  [  6 288   0]
#  [  4   7  21]]
# Normalized confusion matrix
# [[0.80555556 0.13888889 0.05555556]
#  [0.02040816 0.97959184 0.        ]
#  [0.125      0.21875    0.65625   ]]

# %% [markdown]
# ### images - svm, texts - 2_3

# %%
X_train = np.concatenate((images_train_svm, texts_train_net_2_3), axis=1)
X_test = np.concatenate((images_test_svm, texts_test_net_2_3), axis=1)

# %%
run_knn_uniform(X_train, X_test)
# Out:
# test accuracy:  0.9282
#
# TRAIN CONFUSION MATRIX
# Confusion matrix, without normalization
# [[ 304   10    1]
#  [   7 2627    3]
#  [   1   29  252]]
# Normalized confusion matrix
# [[0.96507937 0.03174603 0.0031746 ]
#  [0.00265453 0.99620781 0.00113766]
#  [0.0035461  0.10283688 0.89361702]]
# TEST CONFUSION MATRIX
# Confusion matrix, without normalization
# [[ 28   8   0]
#  [  6 287   1]
#  [  3   8  21]]
# Normalized confusion matrix
# [[0.77777778 0.22222222 0.        ]
#  [0.02040816 0.97619048 0.00340136]
#  [0.09375    0.25       0.65625   ]]

# %%
run_knn_distance(X_train, X_test)
# Out:
# test accuracy:  0.9282
#
# TRAIN CONFUSION MATRIX
# Confusion matrix, without normalization
# [[ 304   10    1]
#  [   7 2627    3]
#  [   1   25  256]]
# Normalized confusion matrix
# [[0.96507937 0.03174603 0.0031746 ]
#  [0.00265453 0.99620781 0.00113766]
#  [0.0035461  0.08865248 0.90780142]]
# TEST CONFUSION MATRIX
# Confusion matrix, without normalization
# [[ 28   6   2]
#  [  6 287   1]
#  [  3   8  21]]
# Normalized confusion matrix
# [[0.77777778 0.16666667 0.05555556]
#  [0.02040816 0.97619048 0.00340136]
#  [0.09375    0.25       0.65625   ]]

# %%
run_svm(X_train, X_test)
# Out:
# test accuracy:  0.9282
#
# TRAIN CONFUSION MATRIX
# Confusion matrix, without normalization
# [[ 304   10    1]
#  [   7 2627    3]
#  [   1   25  256]]
# Normalized confusion matrix
# [[0.96507937 0.03174603 0.0031746 ]
#  [0.00265453 0.99620781 0.00113766]
#  [0.0035461  0.08865248 0.90780142]]
# TEST CONFUSION MATRIX
# Confusion matrix, without normalization
# [[ 28   6   2]
#  [  6 287   1]
#  [  3   8  21]]
# Normalized confusion matrix
# [[0.77777778 0.16666667 0.05555556]
#  [0.02040816 0.97619048 0.00340136]
#  [0.09375    0.25       0.65625   ]]

# %%
run_meta_net(X_train, X_test)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_7 (Dense)              (None, 512)               1536
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_8 (Dense)              (None, 256)               131328
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_9 (Dense)              (None, 3)                 771
# =================================================================
# Total params: 133,635
# Trainable params: 133,635
# Non-trainable params: 0
# _________________________________________________________________
# None
# Train on 3234 samples, validate on 362 samples
# Epoch 1/300
# 3234/3234 [==============================] - 2s 491us/step - loss: 0.5739 - acc: 0.8411 - val_loss: 0.5237 - val_acc: 0.8729
# Epoch 2/300
# 3234/3234 [==============================] - 1s 188us/step - loss: 0.3005 - acc: 0.9289 - val_loss: 0.4309 - val_acc: 0.9282
# Epoch 3/300
# 3234/3234 [==============================] - 1s 183us/step - loss: 0.1189 - acc: 0.9808 - val_loss: 0.4496 - val_acc: 0.9282
# Epoch 4/300
# 3234/3234 [==============================] - 1s 181us/step - loss: 0.0866 - acc: 0.9852 - val_loss: 0.4384 - val_acc: 0.9282
# Epoch 5/300
# 3234/3234 [==============================] - 1s 191us/step - loss: 0.0853 - acc: 0.9839 - val_loss: 0.4291 - val_acc: 0.9282
# Epoch 6/300
# 3234/3234 [==============================] - 1s 184us/step - loss: 0.0864 - acc: 0.9836 - val_loss: 0.4447 - val_acc: 0.9282
# Epoch 7/300
# 3234/3234 [==============================] - 1s 188us/step - loss: 0.0824 - acc: 0.9848 - val_loss: 0.4599 - val_acc: 0.9199
# Epoch 8/300
# 3234/3234 [==============================] - 1s 184us/step - loss: 0.0830 - acc: 0.9848 - val_loss: 0.4440 - val_acc: 0.9282
# Epoch 9/300
# 3234/3234 [==============================] - 1s 187us/step - loss: 0.0849 - acc: 0.9811 - val_loss: 0.4409 - val_acc: 0.9282
# Epoch 10/300
# 3234/3234 [==============================] - 1s 193us/step - loss: 0.0830 - acc: 0.9833 - val_loss: 0.4462 - val_acc: 0.9282
# Epoch 11/300
# 3234/3234 [==============================] - 1s 187us/step - loss: 0.0876 - acc: 0.9839 - val_loss: 0.4662 - val_acc: 0.9199
# Epoch 12/300
# 3234/3234 [==============================] - 1s 184us/step - loss: 0.0859 - acc: 0.9842 - val_loss: 0.4499 - val_acc: 0.9199
# test accuracy:  0.9199
#
# TRAIN CONFUSION MATRIX
# Confusion matrix, without normalization
# [[ 300   14    1]
#  [   7 2627    3]
#  [   1   25  256]]
# Normalized confusion matrix
# [[0.95238095 0.04444444 0.0031746 ]
#  [0.00265453 0.99620781 0.00113766]
#  [0.0035461  0.08865248 0.90780142]]
# TEST CONFUSION MATRIX
# Confusion matrix, without normalization
# [[ 25   9   2]
#  [  6 287   1]
#  [  3   8  21]]
# Normalized confusion matrix
# [[0.69444444 0.25       0.05555556]
#  [0.02040816 0.97619048 0.00340136]
#  [0.09375    0.25       0.65625   ]]

# %% [markdown]
# ### images - svm, texts - 3_3

# %%
X_train = np.concatenate((images_train_svm, texts_train_net_3_3), axis=1)
X_test = np.concatenate((images_test_svm, texts_test_net_3_3), axis=1)

# %%
run_knn_uniform(X_train, X_test)
# Out:
# test accuracy:  0.9254
#
# TRAIN CONFUSION MATRIX
# Confusion matrix, without normalization
# [[ 304   10    1]
#  [   7 2627    3]
#  [   1   28  253]]
# Normalized confusion matrix
# [[0.96507937 0.03174603 0.0031746 ]
#  [0.00265453 0.99620781 0.00113766]
#  [0.0035461  0.09929078 0.89716312]]
# TEST CONFUSION MATRIX
# Confusion matrix, without normalization
# [[ 28   8   0]
#  [  6 287   1]
#  [  3   9  20]]
# Normalized confusion matrix
# [[0.77777778 0.22222222 0.        ]
#  [0.02040816 0.97619048 0.00340136]
#  [0.09375    0.28125    0.625     ]]

# %%
run_knn_distance(X_train, X_test)
# Out:
# test accuracy:  0.9282
#
# TRAIN CONFUSION MATRIX
# Confusion matrix, without normalization
# [[ 304   10    1]
#  [   7 2627    3]
#  [   1   25  256]]
# Normalized confusion matrix
# [[0.96507937 0.03174603 0.0031746 ]
#  [0.00265453 0.99620781 0.00113766]
#  [0.0035461  0.08865248 0.90780142]]
# TEST CONFUSION MATRIX
# Confusion matrix, without normalization
# [[ 28   6   2]
#  [  6 287   1]
#  [  3   8  21]]
# Normalized confusion matrix
# [[0.77777778 0.16666667 0.05555556]
#  [0.02040816 0.97619048 0.00340136]
#  [0.09375    0.25       0.65625   ]]

# %%
run_svm(X_train, X_test)
# Out:
# test accuracy:  0.9282
#
# TRAIN CONFUSION MATRIX
# Confusion matrix, without normalization
# [[ 304   10    1]
#  [   7 2627    3]
#  [   1   25  256]]
# Normalized confusion matrix
# [[0.96507937 0.03174603 0.0031746 ]
#  [0.00265453 0.99620781 0.00113766]
#  [0.0035461  0.08865248 0.90780142]]
# TEST CONFUSION MATRIX
# Confusion matrix, without normalization
# [[ 28   6   2]
#  [  6 287   1]
#  [  3   8  21]]
# Normalized confusion matrix
# [[0.77777778 0.16666667 0.05555556]
#  [0.02040816 0.97619048 0.00340136]
#  [0.09375    0.25       0.65625   ]]

# %%
run_meta_net(X_train, X_test)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_13 (Dense)             (None, 512)               1536
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_14 (Dense)             (None, 256)               131328
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_15 (Dense)             (None, 3)                 771
# =================================================================
# Total params: 133,635
# Trainable params: 133,635
# Non-trainable params: 0
# _________________________________________________________________
# None
# Train on 3234 samples, validate on 362 samples
# Epoch 1/300
# 3234/3234 [==============================] - 2s 529us/step - loss: 0.5574 - acc: 0.8361 - val_loss: 0.5446 - val_acc: 0.8729
# Epoch 2/300
# 3234/3234 [==============================] - 1s 191us/step - loss: 0.3061 - acc: 0.9307 - val_loss: 0.4149 - val_acc: 0.9282
# Epoch 3/300
# 3234/3234 [==============================] - 1s 187us/step - loss: 0.1148 - acc: 0.9824 - val_loss: 0.4399 - val_acc: 0.9282
# Epoch 4/300
# 3234/3234 [==============================] - 1s 190us/step - loss: 0.0911 - acc: 0.9839 - val_loss: 0.4340 - val_acc: 0.9282
# Epoch 5/300
# 3234/3234 [==============================] - 1s 194us/step - loss: 0.0860 - acc: 0.9839 - val_loss: 0.4418 - val_acc: 0.9254
# Epoch 6/300
# 3234/3234 [==============================] - 1s 191us/step - loss: 0.0833 - acc: 0.9842 - val_loss: 0.4454 - val_acc: 0.9171
# Epoch 7/300
# 3234/3234 [==============================] - 1s 196us/step - loss: 0.0852 - acc: 0.9839 - val_loss: 0.4600 - val_acc: 0.9254
# Epoch 8/300
# 3234/3234 [==============================] - 1s 197us/step - loss: 0.0846 - acc: 0.9833 - val_loss: 0.4604 - val_acc: 0.9254
# Epoch 9/300
# 3234/3234 [==============================] - 1s 186us/step - loss: 0.0874 - acc: 0.9824 - val_loss: 0.4586 - val_acc: 0.9282
# test accuracy:  0.9282
#
# TRAIN CONFUSION MATRIX
# Confusion matrix, without normalization
# [[ 304   10    1]
#  [   7 2627    3]
#  [   1   25  256]]
# Normalized confusion matrix
# [[0.96507937 0.03174603 0.0031746 ]
#  [0.00265453 0.99620781 0.00113766]
#  [0.0035461  0.08865248 0.90780142]]
# TEST CONFUSION MATRIX
# Confusion matrix, without normalization
# [[ 28   6   2]
#  [  6 287   1]
#  [  3   8  21]]
# Normalized confusion matrix
# [[0.77777778 0.16666667 0.05555556]
#  [0.02040816 0.97619048 0.00340136]
#  [0.09375    0.25       0.65625   ]]

# %% [markdown]
# ### images - svm, texts - 2_4

# %%
X_train = np.concatenate((images_train_svm, texts_train_net_2_4), axis=1)
X_test = np.concatenate((images_test_svm, texts_test_net_2_4), axis=1)

# %% [markdown]
# #### knn_distance

# %%
run_knn_distance(X_train, X_test)
# Out:
# test accuracy:  0.9282
#
# TRAIN CONFUSION MATRIX
# Confusion matrix, without normalization
# [[ 304   10    1]
#  [   7 2627    3]
#  [   1   25  256]]
# Normalized confusion matrix
# [[0.96507937 0.03174603 0.0031746 ]
#  [0.00265453 0.99620781 0.00113766]
#  [0.0035461  0.08865248 0.90780142]]
# TEST CONFUSION MATRIX
# Confusion matrix, without normalization
# [[ 28   6   2]
#  [  6 287   1]
#  [  3   8  21]]
# Normalized confusion matrix
# [[0.77777778 0.16666667 0.05555556]
#  [0.02040816 0.97619048 0.00340136]
#  [0.09375    0.25       0.65625   ]]

# %%
run_knn_uniform(X_train, X_test)
# Out:
# test accuracy:  0.9254
#
# TRAIN CONFUSION MATRIX
# Confusion matrix, without normalization
# [[ 304   10    1]
#  [   7 2627    3]
#  [   1   28  253]]
# Normalized confusion matrix
# [[0.96507937 0.03174603 0.0031746 ]
#  [0.00265453 0.99620781 0.00113766]
#  [0.0035461  0.09929078 0.89716312]]
# TEST CONFUSION MATRIX
# Confusion matrix, without normalization
# [[ 28   8   0]
#  [  6 287   1]
#  [  3   9  20]]
# Normalized confusion matrix
# [[0.77777778 0.22222222 0.        ]
#  [0.02040816 0.97619048 0.00340136]
#  [0.09375    0.28125    0.625     ]]

# %%
run_svm(X_train, X_test)
# Out:
# test accuracy:  0.9282
#
# TRAIN CONFUSION MATRIX
# Confusion matrix, without normalization
# [[ 304   10    1]
#  [   7 2627    3]
#  [   1   25  256]]
# Normalized confusion matrix
# [[0.96507937 0.03174603 0.0031746 ]
#  [0.00265453 0.99620781 0.00113766]
#  [0.0035461  0.08865248 0.90780142]]
# TEST CONFUSION MATRIX
# Confusion matrix, without normalization
# [[ 28   6   2]
#  [  6 287   1]
#  [  3   8  21]]
# Normalized confusion matrix
# [[0.77777778 0.16666667 0.05555556]
#  [0.02040816 0.97619048 0.00340136]
#  [0.09375    0.25       0.65625   ]]

# %%
run_meta_net(X_train, X_test)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_16 (Dense)             (None, 512)               1536
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_17 (Dense)             (None, 256)               131328
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_18 (Dense)             (None, 3)                 771
# =================================================================
# Total params: 133,635
# Trainable params: 133,635
# Non-trainable params: 0
# _________________________________________________________________
# None
# Train on 3234 samples, validate on 362 samples
# Epoch 1/300
# 3234/3234 [==============================] - 2s 614us/step - loss: 0.5775 - acc: 0.8324 - val_loss: 0.5242 - val_acc: 0.8729
# Epoch 2/300
# 3234/3234 [==============================] - 1s 192us/step - loss: 0.3071 - acc: 0.9280 - val_loss: 0.4274 - val_acc: 0.9282
# Epoch 3/300
# 3234/3234 [==============================] - 1s 189us/step - loss: 0.1178 - acc: 0.9799 - val_loss: 0.4113 - val_acc: 0.9282
# Epoch 4/300
# 3234/3234 [==============================] - 1s 188us/step - loss: 0.0845 - acc: 0.9852 - val_loss: 0.4058 - val_acc: 0.9282
# Epoch 5/300
# 3234/3234 [==============================] - 1s 195us/step - loss: 0.0802 - acc: 0.9842 - val_loss: 0.4191 - val_acc: 0.9171
# Epoch 6/300
# 3234/3234 [==============================] - 1s 193us/step - loss: 0.0819 - acc: 0.9830 - val_loss: 0.3963 - val_acc: 0.9171
# Epoch 7/300
# 3234/3234 [==============================] - 1s 189us/step - loss: 0.0818 - acc: 0.9827 - val_loss: 0.4108 - val_acc: 0.9171
# Epoch 8/300
# 3234/3234 [==============================] - 1s 195us/step - loss: 0.0804 - acc: 0.9839 - val_loss: 0.4193 - val_acc: 0.9171
# Epoch 9/300
# 3234/3234 [==============================] - 1s 191us/step - loss: 0.0796 - acc: 0.9836 - val_loss: 0.4235 - val_acc: 0.9171
# Epoch 10/300
# 3234/3234 [==============================] - 1s 193us/step - loss: 0.0775 - acc: 0.9842 - val_loss: 0.4272 - val_acc: 0.9171
# Epoch 11/300
# 3234/3234 [==============================] - 1s 189us/step - loss: 0.0766 - acc: 0.9836 - val_loss: 0.4161 - val_acc: 0.9171
# Epoch 12/300
# 3234/3234 [==============================] - 1s 193us/step - loss: 0.0809 - acc: 0.9836 - val_loss: 0.4221 - val_acc: 0.9171
# Epoch 13/300
# 3234/3234 [==============================] - 1s 189us/step - loss: 0.0757 - acc: 0.9839 - val_loss: 0.4182 - val_acc: 0.9171
# test accuracy:  0.9171
#
# TRAIN CONFUSION MATRIX
# Confusion matrix, without normalization
# [[ 301   13    1]
#  [   7 2627    3]
#  [   0   29  253]]
# Normalized confusion matrix
# [[0.95555556 0.04126984 0.0031746 ]
#  [0.00265453 0.99620781 0.00113766]
#  [0.         0.10283688 0.89716312]]
# TEST CONFUSION MATRIX
# Confusion matrix, without normalization
# [[ 25  11   0]
#  [  6 287   1]
#  [  2  10  20]]
# Normalized confusion matrix
# [[0.69444444 0.30555556 0.        ]
#  [0.02040816 0.97619048 0.00340136]
#  [0.0625     0.3125     0.625     ]]

# %% [markdown]
# ### images - knn, texts - 2_4

# %%
X_train = np.concatenate((images_train_knn_distance, texts_train_net_2_4), axis=1)
X_test = np.concatenate((images_test_knn_distance, texts_test_net_2_4), axis=1)

# %% [markdown]
# #### knn_uniform

# %%
run_knn_uniform(X_train, X_test)
# Out:
# test accuracy:  0.9309
#
# TRAIN CONFUSION MATRIX
# Confusion matrix, without normalization
# [[ 314    1    0]
#  [   0 2637    0]
#  [   0   11  271]]
# Normalized confusion matrix
# [[0.9968254  0.0031746  0.        ]
#  [0.         1.         0.        ]
#  [0.         0.03900709 0.96099291]]
# TEST CONFUSION MATRIX
# Confusion matrix, without normalization
# [[ 29   7   0]
#  [  6 288   0]
#  [  4   8  20]]
# Normalized confusion matrix
# [[0.80555556 0.19444444 0.        ]
#  [0.02040816 0.97959184 0.        ]
#  [0.125      0.25       0.625     ]]

# %%
run_knn_distance(X_train, X_test)
# Out:
# test accuracy:  0.9337
#
# TRAIN CONFUSION MATRIX
# Confusion matrix, without normalization
# [[ 314    1    0]
#  [   0 2637    0]
#  [   0    6  276]]
# Normalized confusion matrix
# [[0.9968254 0.0031746 0.       ]
#  [0.        1.        0.       ]
#  [0.        0.0212766 0.9787234]]
# TEST CONFUSION MATRIX
# Confusion matrix, without normalization
# [[ 29   5   2]
#  [  6 288   0]
#  [  4   7  21]]
# Normalized confusion matrix
# [[0.80555556 0.13888889 0.05555556]
#  [0.02040816 0.97959184 0.        ]
#  [0.125      0.21875    0.65625   ]]

# %%
run_svm(X_train, X_test)
# Out:
# test accuracy:  0.9337
#
# TRAIN CONFUSION MATRIX
# Confusion matrix, without normalization
# [[ 314    1    0]
#  [   0 2637    0]
#  [   0    6  276]]
# Normalized confusion matrix
# [[0.9968254 0.0031746 0.       ]
#  [0.        1.        0.       ]
#  [0.        0.0212766 0.9787234]]
# TEST CONFUSION MATRIX
# Confusion matrix, without normalization
# [[ 29   5   2]
#  [  6 288   0]
#  [  4   7  21]]
# Normalized confusion matrix
# [[0.80555556 0.13888889 0.05555556]
#  [0.02040816 0.97959184 0.        ]
#  [0.125      0.21875    0.65625   ]]

# %%
run_meta_net(X_train, X_test)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_19 (Dense)             (None, 512)               1536
# _________________________________________________________________
# dropout_13 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_20 (Dense)             (None, 256)               131328
# _________________________________________________________________
# dropout_14 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_21 (Dense)             (None, 3)                 771
# =================================================================
# Total params: 133,635
# Trainable params: 133,635
# Non-trainable params: 0
# _________________________________________________________________
# None
# Train on 3234 samples, validate on 362 samples
# Epoch 1/300
# 3234/3234 [==============================] - 2s 605us/step - loss: 0.5621 - acc: 0.8324 - val_loss: 0.5139 - val_acc: 0.8702
# Epoch 2/300
# 3234/3234 [==============================] - 1s 191us/step - loss: 0.2544 - acc: 0.9372 - val_loss: 0.4634 - val_acc: 0.9337
# Epoch 3/300
# 3234/3234 [==============================] - 1s 190us/step - loss: 0.0599 - acc: 0.9910 - val_loss: 0.5062 - val_acc: 0.9337
# Epoch 4/300
# 3234/3234 [==============================] - 1s 185us/step - loss: 0.0255 - acc: 0.9975 - val_loss: 0.5251 - val_acc: 0.9337
# Epoch 5/300
# 3234/3234 [==============================] - 1s 190us/step - loss: 0.0210 - acc: 0.9975 - val_loss: 0.5386 - val_acc: 0.9337
# Epoch 6/300
# 3234/3234 [==============================] - 1s 186us/step - loss: 0.0172 - acc: 0.9975 - val_loss: 0.5653 - val_acc: 0.9337
# Epoch 7/300
# 3234/3234 [==============================] - 1s 185us/step - loss: 0.0190 - acc: 0.9978 - val_loss: 0.5773 - val_acc: 0.9337
# Epoch 8/300
# 3234/3234 [==============================] - 1s 183us/step - loss: 0.0170 - acc: 0.9978 - val_loss: 0.5939 - val_acc: 0.9337
# Epoch 9/300
# 3234/3234 [==============================] - 1s 171us/step - loss: 0.0189 - acc: 0.9975 - val_loss: 0.5947 - val_acc: 0.9337
# test accuracy:  0.9337
#
# TRAIN CONFUSION MATRIX
# Confusion matrix, without normalization
# [[ 314    1    0]
#  [   0 2637    0]
#  [   0    6  276]]
# Normalized confusion matrix
# [[0.9968254 0.0031746 0.       ]
#  [0.        1.        0.       ]
#  [0.        0.0212766 0.9787234]]
# TEST CONFUSION MATRIX
# Confusion matrix, without normalization
# [[ 29   5   2]
#  [  6 288   0]
#  [  4   7  21]]
# Normalized confusion matrix
# [[0.80555556 0.13888889 0.05555556]
#  [0.02040816 0.97959184 0.        ]
#  [0.125      0.21875    0.65625   ]]
