# %%
import numpy as np
import os
import math
import pandas as pd
from collections import Counter
import itertools

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.svm import SVC
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix

import matplotlib.pyplot as plt

from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score
from sklearn import neighbors
from sklearn.svm import SVC

import keras
from keras.models import Sequential
from keras.layers import Dense, Activation, Flatten, Dropout
from keras.optimizers import SGD, Adadelta, Adam
from keras.applications.xception import Xception
from keras.applications.vgg16 import VGG16

# %matplotlib inline
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
from confusion_matrix import print_confusion_matrix

# %%
import tensorflow as tf
os.environ["CUDA_VISIBLE_DEVICES"] = '0' #use GPU with ID=0
config = tf.ConfigProto()
config.gpu_options.per_process_gpu_memory_fraction = 0.5 # maximun alloc gpu50% of MEM
config.gpu_options.allow_growth = True #allocate dynamically
sess = tf.Session(config = config)

# %%
main_path_word_emb = "C:/Users/svruchtel/Documents/1/Texts classification/LSTM_results_word_emb/"
main_path_char_emb = "C:/Users/svruchtel/Documents/1/Texts classification/LSTM_results_char_emb/"

# %%
y_train_word_emb = np.load(main_path_word_emb + "France_ByShape_2nd_net_train_y.npy")
y_train_char_emb = np.load(main_path_char_emb + "France_ByShape_1st_net_train_y.npy")

y_test_word_emb = np.load(main_path_word_emb + "France_ByShape_2nd_net_test_y.npy")
y_test_char_emb = np.load(main_path_char_emb + "France_ByShape_1st_net_test_y.npy")

# %%
y_train = y_train_word_emb
y_test = y_test_word_emb

# %%
# print(y_test_word_emb.shape)
# print(y_test_char_emb.shape)
# Out:
# (362, 3)
# (362, 3)

# %%
# for idx in range(len(y_train_2nd_net_word_emb)):
#     if y_train_2nd_net_word_emb[0].any() != y_train_3rd_net_word_emb[0].any():
#         print("problem")

# %%
# for idx in range(len(y_train_word_emb)):
#     if y_train_word_emb[0].any() != y_train_word_emb[0].any():
#         print("problem")

# %%
# let's load what we need
X_train_2nd_net_word_emb = np.load(main_path_word_emb + "France_ByShape_2nd_net_train_X.npy")
X_train_3rd_net_word_emb = np.load(main_path_word_emb + "France_ByShape_3rd_net_train_X.npy")
X_train_4th_net_word_emb = np.load(main_path_word_emb + "France_ByShape_4th_net_train_X.npy")

X_test_2nd_net_word_emb = np.load(main_path_word_emb + "France_ByShape_2nd_net_test_X.npy")
X_test_3rd_net_word_emb = np.load(main_path_word_emb + "France_ByShape_3rd_net_test_X.npy")
X_test_4th_net_word_emb = np.load(main_path_word_emb + "France_ByShape_4th_net_test_X.npy")

X_train_3rd_net_char_emb = np.load(main_path_char_emb + "France_ByShape_3rd_net_train_X_100_chars.npy")
X_train_4th_net_char_emb = np.load(main_path_char_emb + "France_ByShape_4th_net_train_X_100_chars.npy")

X_test_3rd_net_char_emb = np.load(main_path_char_emb + "France_ByShape_3rd_net_test_X_100_chars.npy")
X_test_4th_net_char_emb = np.load(main_path_char_emb + "France_ByShape_4th_net_test_X_100_chars.npy")

# %%
CATEGORIES_COUNT = 3

# %%
X_train_2_3 = np.concatenate((X_train_2nd_net_word_emb, X_train_3rd_net_char_emb), axis=1)
X_test_2_3 = np.concatenate((X_test_2nd_net_word_emb, X_test_3rd_net_char_emb), axis=1)

X_train_2_4 = np.concatenate((X_train_2nd_net_word_emb, X_train_4th_net_char_emb), axis=1)
X_test_2_4 = np.concatenate((X_test_2nd_net_word_emb, X_test_4th_net_char_emb), axis=1)

X_train_3_3 = np.concatenate((X_train_3rd_net_word_emb, X_train_3rd_net_char_emb), axis=1)
X_test_3_3 = np.concatenate((X_test_3rd_net_word_emb, X_test_3rd_net_char_emb), axis=1)

X_train_3_4 = np.concatenate((X_train_3rd_net_word_emb, X_train_4th_net_char_emb), axis=1)
X_test_3_4 = np.concatenate((X_test_3rd_net_word_emb, X_test_4th_net_char_emb), axis=1)

X_train_4_3 = np.concatenate((X_train_4th_net_word_emb, X_train_3rd_net_char_emb), axis=1)
X_test_4_3 = np.concatenate((X_test_4th_net_word_emb, X_test_3rd_net_char_emb), axis=1)

X_train_4_4 = np.concatenate((X_train_4th_net_word_emb, X_train_4th_net_char_emb), axis=1)
X_test_4_4 = np.concatenate((X_test_4th_net_word_emb, X_test_4th_net_char_emb), axis=1)

# %% [markdown]
# ## knn_uniform

# %% [markdown]
# #### 2_word, 3_char

# %%
X_train = X_train_2_3
X_test = X_test_2_3

knn_uniform_15 = neighbors.KNeighborsClassifier(n_neighbors=15, weights='uniform')
knn_uniform_15.fit(X_train, y_train)

acc_knn_uniform_15 = accuracy_score(y_test, knn_uniform_15.predict(X_test))
print("test accuracy:  %.4f" % acc_knn_uniform_15)
print("")

y_train_pred = (knn_uniform_15.predict(X_train).round()).argmax(axis=1)
y_test_pred = (knn_uniform_15.predict(X_test).round()).argmax(axis=1)

print("TRAIN CONFUSION MATRIX")
print_confusion_matrix(X_train, (y_train.round()).argmax(axis=1), y_train_pred.round(), categories_count=CATEGORIES_COUNT)

print("")
print("TEST CONFUSION MATRIX")
print_confusion_matrix(X_test, (y_test.round()).argmax(axis=1), y_test_pred.round(), categories_count=CATEGORIES_COUNT)
# Out:
# test accuracy:  0.8895
#
# TRAIN CONFUSION MATRIX
# Confusion matrix, without normalization
# [[ 213   97    5]
#  [  29 2596   12]
#  [   4   49  229]]
# Normalized confusion matrix
# [[0.67619048 0.30793651 0.01587302]
#  [0.01099735 0.98445203 0.00455063]
#  [0.0141844  0.17375887 0.81205674]]
# TEST CONFUSION MATRIX
# Confusion matrix, without normalization
# [[ 19  15   2]
#  [  3 280  11]
#  [  1   8  23]]
# Normalized confusion matrix
# [[0.52777778 0.41666667 0.05555556]
#  [0.01020408 0.95238095 0.03741497]
#  [0.03125    0.25       0.71875   ]]

# %% [markdown]
# #### 2 word, 4 char

# %%
X_train = X_train_2_4
X_test = X_test_2_4

knn_uniform_15 = neighbors.KNeighborsClassifier(n_neighbors=15, weights='uniform')
knn_uniform_15.fit(X_train, y_train)

acc_knn_uniform_15 = accuracy_score(y_test, knn_uniform_15.predict(X_test))
print("test accuracy:  %.4f" % acc_knn_uniform_15)
print("")

y_train_pred = (knn_uniform_15.predict(X_train).round()).argmax(axis=1)
y_test_pred = (knn_uniform_15.predict(X_test).round()).argmax(axis=1)

print("TRAIN CONFUSION MATRIX")
print_confusion_matrix(X_train, (y_train.round()).argmax(axis=1), y_train_pred.round(), categories_count=CATEGORIES_COUNT)

print("")
print("TEST CONFUSION MATRIX")
print_confusion_matrix(X_test, (y_test.round()).argmax(axis=1), y_test_pred.round(), categories_count=CATEGORIES_COUNT)
# Out:
# test accuracy:  0.8950
#
# TRAIN CONFUSION MATRIX
# Confusion matrix, without normalization
# [[ 220   91    4]
#  [  32 2594   11]
#  [   4   53  225]]
# Normalized confusion matrix
# [[0.6984127  0.28888889 0.01269841]
#  [0.012135   0.98369359 0.00417141]
#  [0.0141844  0.18794326 0.79787234]]
# TEST CONFUSION MATRIX
# Confusion matrix, without normalization
# [[ 21  13   2]
#  [  3 281  10]
#  [  1   9  22]]
# Normalized confusion matrix
# [[0.58333333 0.36111111 0.05555556]
#  [0.01020408 0.95578231 0.03401361]
#  [0.03125    0.28125    0.6875    ]]

# %% [markdown]
# #### 3 word, 3 char

# %%
X_train = X_train_3_3
X_test = X_test_3_3

knn_uniform_15 = neighbors.KNeighborsClassifier(n_neighbors=15, weights='uniform')
knn_uniform_15.fit(X_train, y_train)

acc_knn_uniform_15 = accuracy_score(y_test, knn_uniform_15.predict(X_test))
print("test accuracy:  %.4f" % acc_knn_uniform_15)
print("")

y_train_pred = (knn_uniform_15.predict(X_train).round()).argmax(axis=1)
y_test_pred = (knn_uniform_15.predict(X_test).round()).argmax(axis=1)

print("TRAIN CONFUSION MATRIX")
print_confusion_matrix(X_train, (y_train.round()).argmax(axis=1), y_train_pred.round(), categories_count=CATEGORIES_COUNT)

print("")
print("TEST CONFUSION MATRIX")
print_confusion_matrix(X_test, (y_test.round()).argmax(axis=1), y_test_pred.round(), categories_count=CATEGORIES_COUNT)
# Out:
# test accuracy:  0.8674
#
# TRAIN CONFUSION MATRIX
# Confusion matrix, without normalization
# [[ 216   94    5]
#  [  14 2601   22]
#  [   0   43  239]]
# Normalized confusion matrix
# [[0.68571429 0.2984127  0.01587302]
#  [0.00530906 0.98634812 0.00834281]
#  [0.         0.15248227 0.84751773]]
# TEST CONFUSION MATRIX
# Confusion matrix, without normalization
# [[ 20  13   3]
#  [  3 274  17]
#  [  0  12  20]]
# Normalized confusion matrix
# [[0.55555556 0.36111111 0.08333333]
#  [0.01020408 0.93197279 0.05782313]
#  [0.         0.375      0.625     ]]

# %% [markdown]
# #### 3 word, 4 char

# %%
X_train = X_train_3_4
X_test = X_test_3_4

knn_uniform_15 = neighbors.KNeighborsClassifier(n_neighbors=15, weights='uniform')
knn_uniform_15.fit(X_train, y_train)

acc_knn_uniform_15 = accuracy_score(y_test, knn_uniform_15.predict(X_test))
print("test accuracy:  %.4f" % acc_knn_uniform_15)
print("")

y_train_pred = (knn_uniform_15.predict(X_train).round()).argmax(axis=1)
y_test_pred = (knn_uniform_15.predict(X_test).round()).argmax(axis=1)

print("TRAIN CONFUSION MATRIX")
print_confusion_matrix(X_train, (y_train.round()).argmax(axis=1), y_train_pred.round(), categories_count=CATEGORIES_COUNT)

print("")
print("TEST CONFUSION MATRIX")
print_confusion_matrix(X_test, (y_test.round()).argmax(axis=1), y_test_pred.round(), categories_count=CATEGORIES_COUNT)
# Out:
# test accuracy:  0.8591
#
# TRAIN CONFUSION MATRIX
# Confusion matrix, without normalization
# [[ 224   87    4]
#  [  18 2600   19]
#  [   1   43  238]]
# Normalized confusion matrix
# [[0.71111111 0.27619048 0.01269841]
#  [0.00682594 0.9859689  0.00720516]
#  [0.0035461  0.15248227 0.84397163]]
# TEST CONFUSION MATRIX
# Confusion matrix, without normalization
# [[ 18  15   3]
#  [  3 274  17]
#  [  1  12  19]]
# Normalized confusion matrix
# [[0.5        0.41666667 0.08333333]
#  [0.01020408 0.93197279 0.05782313]
#  [0.03125    0.375      0.59375   ]]

# %% [markdown]
# #### 4 word, 3 char

# %%
X_train = X_train_4_3
X_test = X_test_4_3

knn_uniform_15 = neighbors.KNeighborsClassifier(n_neighbors=15, weights='uniform')
knn_uniform_15.fit(X_train, y_train)

acc_knn_uniform_15 = accuracy_score(y_test, knn_uniform_15.predict(X_test))
print("test accuracy:  %.4f" % acc_knn_uniform_15)
print("")

y_train_pred = (knn_uniform_15.predict(X_train).round()).argmax(axis=1)
y_test_pred = (knn_uniform_15.predict(X_test).round()).argmax(axis=1)

print("TRAIN CONFUSION MATRIX")
print_confusion_matrix(X_train, (y_train.round()).argmax(axis=1), y_train_pred.round(), categories_count=CATEGORIES_COUNT)

print("")
print("TEST CONFUSION MATRIX")
print_confusion_matrix(X_test, (y_test.round()).argmax(axis=1), y_test_pred.round(), categories_count=CATEGORIES_COUNT)
# Out:
# test accuracy:  0.8757
#
# TRAIN CONFUSION MATRIX
# Confusion matrix, without normalization
# [[ 209  102    4]
#  [  16 2593   28]
#  [   2   46  234]]
# Normalized confusion matrix
# [[0.66349206 0.32380952 0.01269841]
#  [0.0060675  0.98331437 0.01061813]
#  [0.0070922  0.16312057 0.82978723]]
# TEST CONFUSION MATRIX
# Confusion matrix, without normalization
# [[ 16  14   6]
#  [  3 279  12]
#  [  0  10  22]]
# Normalized confusion matrix
# [[0.44444444 0.38888889 0.16666667]
#  [0.01020408 0.94897959 0.04081633]
#  [0.         0.3125     0.6875    ]]

# %% [markdown]
# #### 4 word, 4 char

# %%
X_train = X_train_4_4
X_test = X_test_4_4

knn_uniform_15 = neighbors.KNeighborsClassifier(n_neighbors=15, weights='uniform')
knn_uniform_15.fit(X_train, y_train)

acc_knn_uniform_15 = accuracy_score(y_test, knn_uniform_15.predict(X_test))
print("test accuracy:  %.4f" % acc_knn_uniform_15)
print("")

y_train_pred = (knn_uniform_15.predict(X_train).round()).argmax(axis=1)
y_test_pred = (knn_uniform_15.predict(X_test).round()).argmax(axis=1)

print("TRAIN CONFUSION MATRIX")
print_confusion_matrix(X_train, (y_train.round()).argmax(axis=1), y_train_pred.round(), categories_count=CATEGORIES_COUNT)

print("")
print("TEST CONFUSION MATRIX")
print_confusion_matrix(X_test, (y_test.round()).argmax(axis=1), y_test_pred.round(), categories_count=CATEGORIES_COUNT)
# Out:
# test accuracy:  0.8757
#
# TRAIN CONFUSION MATRIX
# Confusion matrix, without normalization
# [[ 208  103    4]
#  [  14 2594   29]
#  [   0   45  237]]
# Normalized confusion matrix
# [[0.66031746 0.32698413 0.01269841]
#  [0.00530906 0.98369359 0.01099735]
#  [0.         0.15957447 0.84042553]]
# TEST CONFUSION MATRIX
# Confusion matrix, without normalization
# [[ 17  13   6]
#  [  2 278  14]
#  [  0  10  22]]
# Normalized confusion matrix
# [[0.47222222 0.36111111 0.16666667]
#  [0.00680272 0.94557823 0.04761905]
#  [0.         0.3125     0.6875    ]]

# %% [markdown]
# ### knn_distance

# %% [markdown]
# #### 2 word, 3 char

# %%
X_train = X_train_2_3
X_test = X_test_2_3

knn_distance_15 = neighbors.KNeighborsClassifier(n_neighbors=15, weights='distance')
knn_distance_15.fit(X_train, y_train)

acc_knn_distance_15 = accuracy_score(y_test, knn_distance_15.predict(X_test))
print("test accuracy:  %.4f" % acc_knn_distance_15)
print("")

y_train_pred = (knn_distance_15.predict(X_train).round()).argmax(axis=1)
y_test_pred = (knn_distance_15.predict(X_test).round()).argmax(axis=1)

print("TRAIN CONFUSION MATRIX")
print_confusion_matrix(X_train, (y_train.round()).argmax(axis=1), y_train_pred.round(), categories_count=CATEGORIES_COUNT)

print("")
print("TEST CONFUSION MATRIX")
print_confusion_matrix(X_test, (y_test.round()).argmax(axis=1), y_test_pred.round(), categories_count=CATEGORIES_COUNT)
# Out:
# test accuracy:  0.8867
#
# TRAIN CONFUSION MATRIX
# Confusion matrix, without normalization
# [[ 315    0    0]
#  [   0 2637    0]
#  [   0    0  282]]
# Normalized confusion matrix
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# TEST CONFUSION MATRIX
# Confusion matrix, without normalization
# [[ 19  15   2]
#  [  5 279  10]
#  [  1   8  23]]
# Normalized confusion matrix
# [[0.52777778 0.41666667 0.05555556]
#  [0.0170068  0.94897959 0.03401361]
#  [0.03125    0.25       0.71875   ]]

# %% [markdown]
# #### 2 word, 4 char

# %%
X_train = X_train_2_4
X_test = X_test_2_4

knn_distance_15 = neighbors.KNeighborsClassifier(n_neighbors=15, weights='distance')
knn_distance_15.fit(X_train, y_train)

acc_knn_distance_15 = accuracy_score(y_test, knn_distance_15.predict(X_test))
print("test accuracy:  %.4f" % acc_knn_distance_15)
print("")

y_train_pred = (knn_distance_15.predict(X_train).round()).argmax(axis=1)
y_test_pred = (knn_distance_15.predict(X_test).round()).argmax(axis=1)

print("TRAIN CONFUSION MATRIX")
print_confusion_matrix(X_train, (y_train.round()).argmax(axis=1), y_train_pred.round(), categories_count=CATEGORIES_COUNT)

print("")
print("TEST CONFUSION MATRIX")
print_confusion_matrix(X_test, (y_test.round()).argmax(axis=1), y_test_pred.round(), categories_count=CATEGORIES_COUNT)
# Out:
# test accuracy:  0.8867
#
# TRAIN CONFUSION MATRIX
# Confusion matrix, without normalization
# [[ 315    0    0]
#  [   0 2637    0]
#  [   0    0  282]]
# Normalized confusion matrix
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# TEST CONFUSION MATRIX
# Confusion matrix, without normalization
# [[ 18  16   2]
#  [  4 281   9]
#  [  0  10  22]]
# Normalized confusion matrix
# [[0.5        0.44444444 0.05555556]
#  [0.01360544 0.95578231 0.03061224]
#  [0.         0.3125     0.6875    ]]

# %% [markdown]
# #### 3 word, 3 char

# %%
X_train = X_train_3_3
X_test = X_test_3_3

knn_distance_15 = neighbors.KNeighborsClassifier(n_neighbors=15, weights='distance')
knn_distance_15.fit(X_train, y_train)

acc_knn_distance_15 = accuracy_score(y_test, knn_distance_15.predict(X_test))
print("test accuracy:  %.4f" % acc_knn_distance_15)
print("")

y_train_pred = (knn_distance_15.predict(X_train).round()).argmax(axis=1)
y_test_pred = (knn_distance_15.predict(X_test).round()).argmax(axis=1)

print("TRAIN CONFUSION MATRIX")
print_confusion_matrix(X_train, (y_train.round()).argmax(axis=1), y_train_pred.round(), categories_count=CATEGORIES_COUNT)

print("")
print("TEST CONFUSION MATRIX")
print_confusion_matrix(X_test, (y_test.round()).argmax(axis=1), y_test_pred.round(), categories_count=CATEGORIES_COUNT)
# Out:
# test accuracy:  0.8591
#
# TRAIN CONFUSION MATRIX
# Confusion matrix, without normalization
# [[ 315    0    0]
#  [   0 2637    0]
#  [   0    0  282]]
# Normalized confusion matrix
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# TEST CONFUSION MATRIX
# Confusion matrix, without normalization
# [[ 21  12   3]
#  [  5 270  19]
#  [  0  12  20]]
# Normalized confusion matrix
# [[0.58333333 0.33333333 0.08333333]
#  [0.0170068  0.91836735 0.06462585]
#  [0.         0.375      0.625     ]]

# %% [markdown]
# #### 3 word, 4 char

# %%
X_train = X_train_3_4
X_test = X_test_3_4

knn_distance_15 = neighbors.KNeighborsClassifier(n_neighbors=15, weights='distance')
knn_distance_15.fit(X_train, y_train)

acc_knn_distance_15 = accuracy_score(y_test, knn_distance_15.predict(X_test))
print("test accuracy:  %.4f" % acc_knn_distance_15)
print("")

y_train_pred = (knn_distance_15.predict(X_train).round()).argmax(axis=1)
y_test_pred = (knn_distance_15.predict(X_test).round()).argmax(axis=1)

print("TRAIN CONFUSION MATRIX")
print_confusion_matrix(X_train, (y_train.round()).argmax(axis=1), y_train_pred.round(), categories_count=CATEGORIES_COUNT)

print("")
print("TEST CONFUSION MATRIX")
print_confusion_matrix(X_test, (y_test.round()).argmax(axis=1), y_test_pred.round(), categories_count=CATEGORIES_COUNT)
# Out:
# test accuracy:  0.8591
#
# TRAIN CONFUSION MATRIX
# Confusion matrix, without normalization
# [[ 315    0    0]
#  [   0 2637    0]
#  [   0    0  282]]
# Normalized confusion matrix
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# TEST CONFUSION MATRIX
# Confusion matrix, without normalization
# [[ 20  13   3]
#  [  4 272  18]
#  [  1  12  19]]
# Normalized confusion matrix
# [[0.55555556 0.36111111 0.08333333]
#  [0.01360544 0.92517007 0.06122449]
#  [0.03125    0.375      0.59375   ]]

# %% [markdown]
# #### 4 word, 3 char

# %%
X_train = X_train_4_3
X_test = X_test_4_3

knn_distance_15 = neighbors.KNeighborsClassifier(n_neighbors=15, weights='distance')
knn_distance_15.fit(X_train, y_train)

acc_knn_distance_15 = accuracy_score(y_test, knn_distance_15.predict(X_test))
print("test accuracy:  %.4f" % acc_knn_distance_15)
print("")

y_train_pred = (knn_distance_15.predict(X_train).round()).argmax(axis=1)
y_test_pred = (knn_distance_15.predict(X_test).round()).argmax(axis=1)

print("TRAIN CONFUSION MATRIX")
print_confusion_matrix(X_train, (y_train.round()).argmax(axis=1), y_train_pred.round(), categories_count=CATEGORIES_COUNT)

print("")
print("TEST CONFUSION MATRIX")
print_confusion_matrix(X_test, (y_test.round()).argmax(axis=1), y_test_pred.round(), categories_count=CATEGORIES_COUNT)
# Out:
# test accuracy:  0.8674
#
# TRAIN CONFUSION MATRIX
# Confusion matrix, without normalization
# [[ 315    0    0]
#  [   0 2637    0]
#  [   0    0  282]]
# Normalized confusion matrix
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# TEST CONFUSION MATRIX
# Confusion matrix, without normalization
# [[ 16  14   6]
#  [  4 276  14]
#  [  0  10  22]]
# Normalized confusion matrix
# [[0.44444444 0.38888889 0.16666667]
#  [0.01360544 0.93877551 0.04761905]
#  [0.         0.3125     0.6875    ]]

# %% [markdown]
# #### 4 word, 4 char

# %%
X_train = X_train_4_4
X_test = X_test_4_4

knn_distance_15 = neighbors.KNeighborsClassifier(n_neighbors=15, weights='distance')
knn_distance_15.fit(X_train, y_train)

acc_knn_distance_15 = accuracy_score(y_test, knn_distance_15.predict(X_test))
print("test accuracy:  %.4f" % acc_knn_distance_15)
print("")

y_train_pred = (knn_distance_15.predict(X_train).round()).argmax(axis=1)
y_test_pred = (knn_distance_15.predict(X_test).round()).argmax(axis=1)

print("TRAIN CONFUSION MATRIX")
print_confusion_matrix(X_train, (y_train.round()).argmax(axis=1), y_train_pred.round(), categories_count=CATEGORIES_COUNT)

print("")
print("TEST CONFUSION MATRIX")
print_confusion_matrix(X_test, (y_test.round()).argmax(axis=1), y_test_pred.round(), categories_count=CATEGORIES_COUNT)
# Out:
# test accuracy:  0.8840
#
# TRAIN CONFUSION MATRIX
# Confusion matrix, without normalization
# [[ 315    0    0]
#  [   0 2637    0]
#  [   0    0  282]]
# Normalized confusion matrix
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]
# TEST CONFUSION MATRIX
# Confusion matrix, without normalization
# [[ 17  13   6]
#  [  3 283   8]
#  [  0  12  20]]
# Normalized confusion matrix
# [[0.47222222 0.36111111 0.16666667]
#  [0.01020408 0.96258503 0.02721088]
#  [0.         0.375      0.625     ]]

# %% [markdown]
# ### SVM

# %% [markdown]
# #### 2 word, 3 char

# %%
X_train = X_train_2_3
X_test = X_test_2_3

svm = SVC(kernel='rbf')
svm.fit(X_train, (y_train.round()).argmax(axis=1))

acc_svm = accuracy_score((y_test.round()).argmax(axis=1), svm.predict(X_test))
print("test accuracy:  %.4f" % acc_svm)
print("")

y_train_pred = svm.predict(X_train)
y_test_pred = svm.predict(X_test)

print("TRAIN CONFUSION MATRIX")
print_confusion_matrix(X_train, (y_train.round()).argmax(axis=1), y_train_pred, categories_count=CATEGORIES_COUNT)

print("")
print("TEST CONFUSION MATRIX")
print_confusion_matrix(X_test, (y_test.round()).argmax(axis=1), y_test_pred, categories_count=CATEGORIES_COUNT)
# Out:
# test accuracy:  0.8895
#
# TRAIN CONFUSION MATRIX
# Confusion matrix, without normalization
# [[ 188  123    4]
#  [   9 2619    9]
#  [   0   63  219]]
# Normalized confusion matrix
# [[0.5968254  0.39047619 0.01269841]
#  [0.00341297 0.99317406 0.00341297]
#  [0.         0.22340426 0.77659574]]
# TEST CONFUSION MATRIX
# Confusion matrix, without normalization
# [[ 17  17   2]
#  [  1 285   8]
#  [  0  12  20]]
# Normalized confusion matrix
# [[0.47222222 0.47222222 0.05555556]
#  [0.00340136 0.96938776 0.02721088]
#  [0.         0.375      0.625     ]]

# %% [markdown]
# #### 2 word, 4 char

# %%
X_train = X_train_2_4
X_test = X_test_2_4

svm = SVC(kernel='rbf')
svm.fit(X_train, (y_train.round()).argmax(axis=1))

acc_svm = accuracy_score((y_test.round()).argmax(axis=1), svm.predict(X_test))
print("test accuracy:  %.4f" % acc_svm)
print("")

y_train_pred = svm.predict(X_train)
y_test_pred = svm.predict(X_test)

print("TRAIN CONFUSION MATRIX")
print_confusion_matrix(X_train, (y_train.round()).argmax(axis=1), y_train_pred, categories_count=CATEGORIES_COUNT)

print("")
print("TEST CONFUSION MATRIX")
print_confusion_matrix(X_test, (y_test.round()).argmax(axis=1), y_test_pred, categories_count=CATEGORIES_COUNT)
# Out:
# test accuracy:  0.8867
#
# TRAIN CONFUSION MATRIX
# Confusion matrix, without normalization
# [[ 189  122    4]
#  [   9 2619    9]
#  [   0   62  220]]
# Normalized confusion matrix
# [[0.6        0.38730159 0.01269841]
#  [0.00341297 0.99317406 0.00341297]
#  [0.         0.21985816 0.78014184]]
# TEST CONFUSION MATRIX
# Confusion matrix, without normalization
# [[ 17  17   2]
#  [  2 284   8]
#  [  0  12  20]]
# Normalized confusion matrix
# [[0.47222222 0.47222222 0.05555556]
#  [0.00680272 0.96598639 0.02721088]
#  [0.         0.375      0.625     ]]

# %% [markdown]
# #### 3 word, 3 char

# %%
X_train = X_train_3_3
X_test = X_test_3_3

svm = SVC(kernel='rbf')
svm.fit(X_train, (y_train.round()).argmax(axis=1))

acc_svm = accuracy_score((y_test.round()).argmax(axis=1), svm.predict(X_test))
print("test accuracy:  %.4f" % acc_svm)
print("")

y_train_pred = svm.predict(X_train)
y_test_pred = svm.predict(X_test)

print("TRAIN CONFUSION MATRIX")
print_confusion_matrix(X_train, (y_train.round()).argmax(axis=1), y_train_pred, categories_count=CATEGORIES_COUNT)

print("")
print("TEST CONFUSION MATRIX")
print_confusion_matrix(X_test, (y_test.round()).argmax(axis=1), y_test_pred, categories_count=CATEGORIES_COUNT)
# Out:
# test accuracy:  0.8619
#
# TRAIN CONFUSION MATRIX
# Confusion matrix, without normalization
# [[ 196  115    4]
#  [   7 2612   18]
#  [   0   47  235]]
# Normalized confusion matrix
# [[0.62222222 0.36507937 0.01269841]
#  [0.00265453 0.99051953 0.00682594]
#  [0.         0.16666667 0.83333333]]
# TEST CONFUSION MATRIX
# Confusion matrix, without normalization
# [[ 17  16   3]
#  [  1 276  17]
#  [  0  13  19]]
# Normalized confusion matrix
# [[0.47222222 0.44444444 0.08333333]
#  [0.00340136 0.93877551 0.05782313]
#  [0.         0.40625    0.59375   ]]

# %% [markdown]
# #### 3 word, 4 char

# %%
X_train = X_train_3_4
X_test = X_test_3_4

svm = SVC(kernel='rbf')
svm.fit(X_train, (y_train.round()).argmax(axis=1))

acc_svm = accuracy_score((y_test.round()).argmax(axis=1), svm.predict(X_test))
print("test accuracy:  %.4f" % acc_svm)
print("")

y_train_pred = svm.predict(X_train)
y_test_pred = svm.predict(X_test)

print("TRAIN CONFUSION MATRIX")
print_confusion_matrix(X_train, (y_train.round()).argmax(axis=1), y_train_pred, categories_count=CATEGORIES_COUNT)

print("")
print("TEST CONFUSION MATRIX")
print_confusion_matrix(X_test, (y_test.round()).argmax(axis=1), y_test_pred, categories_count=CATEGORIES_COUNT)
# Out:
# test accuracy:  0.8619
#
# TRAIN CONFUSION MATRIX
# Confusion matrix, without normalization
# [[ 197  114    4]
#  [   7 2615   15]
#  [   0   50  232]]
# Normalized confusion matrix
# [[0.62539683 0.36190476 0.01269841]
#  [0.00265453 0.99165719 0.00568828]
#  [0.         0.17730496 0.82269504]]
# TEST CONFUSION MATRIX
# Confusion matrix, without normalization
# [[ 17  16   3]
#  [  1 276  17]
#  [  0  13  19]]
# Normalized confusion matrix
# [[0.47222222 0.44444444 0.08333333]
#  [0.00340136 0.93877551 0.05782313]
#  [0.         0.40625    0.59375   ]]

# %% [markdown]
# #### 4 word, 3 char

# %%
X_train = X_train_4_3
X_test = X_test_4_3

svm = SVC(kernel='rbf')
svm.fit(X_train, (y_train.round()).argmax(axis=1))

acc_svm = accuracy_score((y_test.round()).argmax(axis=1), svm.predict(X_test))
print("test accuracy:  %.4f" % acc_svm)
print("")

y_train_pred = svm.predict(X_train)
y_test_pred = svm.predict(X_test)

print("TRAIN CONFUSION MATRIX")
print_confusion_matrix(X_train, (y_train.round()).argmax(axis=1), y_train_pred, categories_count=CATEGORIES_COUNT)

print("")
print("TEST CONFUSION MATRIX")
print_confusion_matrix(X_test, (y_test.round()).argmax(axis=1), y_test_pred, categories_count=CATEGORIES_COUNT)
# Out:
# test accuracy:  0.8702
#
# TRAIN CONFUSION MATRIX
# Confusion matrix, without normalization
# [[ 206  105    4]
#  [  15 2593   29]
#  [   0   47  235]]
# Normalized confusion matrix
# [[0.65396825 0.33333333 0.01269841]
#  [0.00568828 0.98331437 0.01099735]
#  [0.         0.16666667 0.83333333]]
# TEST CONFUSION MATRIX
# Confusion matrix, without normalization
# [[ 15  15   6]
#  [  2 278  14]
#  [  0  10  22]]
# Normalized confusion matrix
# [[0.41666667 0.41666667 0.16666667]
#  [0.00680272 0.94557823 0.04761905]
#  [0.         0.3125     0.6875    ]]

# %% [markdown]
# #### 4 word, 4 char

# %%
X_train = X_train_4_4
X_test = X_test_4_4

svm = SVC(kernel='rbf')
svm.fit(X_train, (y_train.round()).argmax(axis=1))

acc_svm = accuracy_score((y_test.round()).argmax(axis=1), svm.predict(X_test))
print("test accuracy:  %.4f" % acc_svm)
print("")

y_train_pred = svm.predict(X_train)
y_test_pred = svm.predict(X_test)

print("TRAIN CONFUSION MATRIX")
print_confusion_matrix(X_train, (y_train.round()).argmax(axis=1), y_train_pred, categories_count=CATEGORIES_COUNT)

print("")
print("TEST CONFUSION MATRIX")
print_confusion_matrix(X_test, (y_test.round()).argmax(axis=1), y_test_pred, categories_count=CATEGORIES_COUNT)
# Out:
# test accuracy:  0.8702
#
# TRAIN CONFUSION MATRIX
# Confusion matrix, without normalization
# [[ 206  105    4]
#  [  15 2593   29]
#  [   0   47  235]]
# Normalized confusion matrix
# [[0.65396825 0.33333333 0.01269841]
#  [0.00568828 0.98331437 0.01099735]
#  [0.         0.16666667 0.83333333]]
# TEST CONFUSION MATRIX
# Confusion matrix, without normalization
# [[ 15  15   6]
#  [  2 278  14]
#  [  0  10  22]]
# Normalized confusion matrix
# [[0.41666667 0.41666667 0.16666667]
#  [0.00680272 0.94557823 0.04761905]
#  [0.         0.3125     0.6875    ]]

# %% [markdown]
# ### meta_net

# %% [markdown]
# #### 2 word, 3 char

# %%
# %%time
categories_count = CATEGORIES_COUNT

X_train = X_train_2_3
X_test = X_test_2_3

meta_net = Sequential()
meta_net.add(Dense(512, input_shape=X_train[0].shape))
meta_net.add(Dropout(0.5))
meta_net.add(Dense(256))
meta_net.add(Dropout(0.5))
meta_net.add(Dense(categories_count, activation='softmax'))
meta_net.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
print(meta_net.summary())
    
callback = keras.callbacks.EarlyStopping(monitor='val_loss', min_delta=0, patience=7, verbose=0, mode='auto')
history_callback = meta_net.fit(X_train, y_train, validation_data=(X_test, y_test), 
                                epochs=300, batch_size=100, callbacks=[callback])

test_scores = meta_net.evaluate(X_test, y_test, verbose=0)
    
print("test accuracy:  %.4f" % test_scores[1])
print("")

y_train_pred = (meta_net.predict(X_train).round()).argmax(axis=1)
y_test_pred = (meta_net.predict(X_test).round()).argmax(axis=1)

print("TRAIN CONFUSION MATRIX")
print_confusion_matrix(X_train, (y_train.round()).argmax(axis=1), y_train_pred, categories_count=CATEGORIES_COUNT)

print("")
print("TEST CONFUSION MATRIX")
print_confusion_matrix(X_test, (y_test.round()).argmax(axis=1), y_test_pred, categories_count=CATEGORIES_COUNT)

# and than write results info files
file_path_train = "./Stacking_Results_France_ByShape/meta_net_train_2_3.npy"
file_path_test = "./Stacking_Results_France_ByShape/meta_net_test_2_3.npy"

np.save(file_path_train, y_train_pred)
np.save(file_path_test, y_test_pred)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 512)               3584
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               131328
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 3)                 771
# =================================================================
# Total params: 135,683
# Trainable params: 135,683
# Non-trainable params: 0
# _________________________________________________________________
# None
# Train on 3234 samples, validate on 362 samples
# Epoch 1/300
# 3234/3234 [==============================] - 2s 625us/step - loss: 0.3164 - acc: 0.8939 - val_loss: 0.4085 - val_acc: 0.8867
# Epoch 2/300
# 3234/3234 [==============================] - 1s 199us/step - loss: 0.2190 - acc: 0.9378 - val_loss: 0.4007 - val_acc: 0.8923
# Epoch 3/300
# 3234/3234 [==============================] - 1s 197us/step - loss: 0.2143 - acc: 0.9388 - val_loss: 0.3892 - val_acc: 0.8923
# Epoch 4/300
# 3234/3234 [==============================] - 1s 209us/step - loss: 0.2132 - acc: 0.9378 - val_loss: 0.3855 - val_acc: 0.8895
# Epoch 5/300
# 3234/3234 [==============================] - 1s 184us/step - loss: 0.2171 - acc: 0.9391 - val_loss: 0.3835 - val_acc: 0.8867
# Epoch 6/300
# 3234/3234 [==============================] - 1s 198us/step - loss: 0.2133 - acc: 0.9394 - val_loss: 0.3838 - val_acc: 0.8923
# Epoch 7/300
# 3234/3234 [==============================] - 1s 197us/step - loss: 0.2154 - acc: 0.9378 - val_loss: 0.3721 - val_acc: 0.8867
# Epoch 8/300
# 3234/3234 [==============================] - 1s 185us/step - loss: 0.2181 - acc: 0.9366 - val_loss: 0.3765 - val_acc: 0.8895
# Epoch 9/300
# 3234/3234 [==============================] - 1s 164us/step - loss: 0.2145 - acc: 0.9375 - val_loss: 0.3767 - val_acc: 0.8923
# Epoch 10/300
# 3234/3234 [==============================] - 1s 186us/step - loss: 0.2091 - acc: 0.9378 - val_loss: 0.3842 - val_acc: 0.8923
# Epoch 11/300
# 3234/3234 [==============================] - 1s 190us/step - loss: 0.2126 - acc: 0.9400 - val_loss: 0.3845 - val_acc: 0.8923
# Epoch 12/300
# 3234/3234 [==============================] - 1s 179us/step - loss: 0.2127 - acc: 0.9385 - val_loss: 0.3710 - val_acc: 0.8923
# Epoch 13/300
# 3234/3234 [==============================] - 1s 178us/step - loss: 0.2182 - acc: 0.9400 - val_loss: 0.3700 - val_acc: 0.8867
# Epoch 14/300
# 3234/3234 [==============================] - 1s 209us/step - loss: 0.2101 - acc: 0.9391 - val_loss: 0.3770 - val_acc: 0.8867
# Epoch 15/300
# 3234/3234 [==============================] - 1s 198us/step - loss: 0.2154 - acc: 0.9369 - val_loss: 0.3751 - val_acc: 0.8923
# Epoch 16/300
# 3234/3234 [==============================] - 1s 203us/step - loss: 0.2169 - acc: 0.9388 - val_loss: 0.3684 - val_acc: 0.8895
# Epoch 17/300
# 3234/3234 [==============================] - 1s 197us/step - loss: 0.2121 - acc: 0.9409 - val_loss: 0.3840 - val_acc: 0.8867
# Epoch 18/300
# 3234/3234 [==============================] - 1s 190us/step - loss: 0.2173 - acc: 0.9385 - val_loss: 0.3743 - val_acc: 0.8950
# Epoch 19/300
# 3234/3234 [==============================] - 1s 173us/step - loss: 0.2137 - acc: 0.9372 - val_loss: 0.3666 - val_acc: 0.8923
# Epoch 20/300
# 3234/3234 [==============================] - 1s 183us/step - loss: 0.2158 - acc: 0.9391 - val_loss: 0.3888 - val_acc: 0.8923
# Epoch 21/300
# 3234/3234 [==============================] - 1s 162us/step - loss: 0.2187 - acc: 0.9375 - val_loss: 0.3901 - val_acc: 0.8867
# Epoch 22/300
# 3234/3234 [==============================] - 1s 181us/step - loss: 0.2174 - acc: 0.9394 - val_loss: 0.3934 - val_acc: 0.8867
# Epoch 23/300
# 3234/3234 [==============================] - 1s 195us/step - loss: 0.2141 - acc: 0.9388 - val_loss: 0.3752 - val_acc: 0.8867
# Epoch 24/300
# 3234/3234 [==============================] - 1s 186us/step - loss: 0.2128 - acc: 0.9391 - val_loss: 0.3756 - val_acc: 0.8840
# Epoch 25/300
# 3234/3234 [==============================] - 1s 193us/step - loss: 0.2136 - acc: 0.9366 - val_loss: 0.3796 - val_acc: 0.8840
# Epoch 26/300
# 3234/3234 [==============================] - 1s 189us/step - loss: 0.2146 - acc: 0.9397 - val_loss: 0.3737 - val_acc: 0.8895
# test accuracy:  0.8895
#
# TRAIN CONFUSION MATRIX
# Confusion matrix, without normalization
# [[ 212   99    4]
#  [  27 2600   10]
#  [   3   55  224]]
# Normalized confusion matrix
# [[0.67301587 0.31428571 0.01269841]
#  [0.01023891 0.9859689  0.00379219]
#  [0.0106383  0.19503546 0.79432624]]
# TEST CONFUSION MATRIX
# Confusion matrix, without normalization
# [[ 19  15   2]
#  [  5 281   8]
#  [  1  10  21]]
# Normalized confusion matrix
# [[0.52777778 0.41666667 0.05555556]
#  [0.0170068  0.95578231 0.02721088]
#  [0.03125    0.3125     0.65625   ]]
# Wall time: 20.8 s

# %% [markdown]
# #### 2 word, 4 char

# %%
# %%time
categories_count = CATEGORIES_COUNT

X_train = X_train_2_4
X_test = X_test_2_4

meta_net = Sequential()
meta_net.add(Dense(512, input_shape=X_train[0].shape))
meta_net.add(Dropout(0.5))
meta_net.add(Dense(256))
meta_net.add(Dropout(0.5))
meta_net.add(Dense(categories_count, activation='softmax'))
meta_net.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
print(meta_net.summary())
    
callback = keras.callbacks.EarlyStopping(monitor='val_loss', min_delta=0, patience=7, verbose=0, mode='auto')
history_callback = meta_net.fit(X_train, y_train, validation_data=(X_test, y_test), 
                                epochs=300, batch_size=100, callbacks=[callback])

test_scores = meta_net.evaluate(X_test, y_test, verbose=0)
    
print("test accuracy:  %.4f" % test_scores[1])
print("")

y_train_pred = (meta_net.predict(X_train).round()).argmax(axis=1)
y_test_pred = (meta_net.predict(X_test).round()).argmax(axis=1)

print("TRAIN CONFUSION MATRIX")
print_confusion_matrix(X_train, (y_train.round()).argmax(axis=1), y_train_pred, categories_count=CATEGORIES_COUNT)

print("")
print("TEST CONFUSION MATRIX")
print_confusion_matrix(X_test, (y_test.round()).argmax(axis=1), y_test_pred, categories_count=CATEGORIES_COUNT)

# and than write results info files
file_path_train = "./Stacking_Results_France_ByShape/meta_net_train_2_4.npy"
file_path_test = "./Stacking_Results_France_ByShape/meta_net_test_2_4.npy"

np.save(file_path_train, y_train_pred)
np.save(file_path_test, y_test_pred)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_4 (Dense)              (None, 512)               3584
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 256)               131328
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_6 (Dense)              (None, 3)                 771
# =================================================================
# Total params: 135,683
# Trainable params: 135,683
# Non-trainable params: 0
# _________________________________________________________________
# None
# Train on 3234 samples, validate on 362 samples
# Epoch 1/300
# 3234/3234 [==============================] - 2s 500us/step - loss: 0.3418 - acc: 0.8874 - val_loss: 0.3838 - val_acc: 0.8923
# Epoch 2/300
# 3234/3234 [==============================] - 1s 184us/step - loss: 0.2233 - acc: 0.9397 - val_loss: 0.3848 - val_acc: 0.8950
# Epoch 3/300
# 3234/3234 [==============================] - 1s 195us/step - loss: 0.2145 - acc: 0.9385 - val_loss: 0.3808 - val_acc: 0.8950
# Epoch 4/300
# 3234/3234 [==============================] - 1s 186us/step - loss: 0.2198 - acc: 0.9385 - val_loss: 0.3877 - val_acc: 0.8950
# Epoch 5/300
# 3234/3234 [==============================] - 1s 187us/step - loss: 0.2145 - acc: 0.9391 - val_loss: 0.3944 - val_acc: 0.8950
# Epoch 6/300
# 3234/3234 [==============================] - 1s 200us/step - loss: 0.2130 - acc: 0.9391 - val_loss: 0.3743 - val_acc: 0.8950
# Epoch 7/300
# 3234/3234 [==============================] - 1s 206us/step - loss: 0.2123 - acc: 0.9378 - val_loss: 0.3782 - val_acc: 0.8950
# Epoch 8/300
# 3234/3234 [==============================] - 1s 197us/step - loss: 0.2133 - acc: 0.9400 - val_loss: 0.3718 - val_acc: 0.8950
# Epoch 9/300
# 3234/3234 [==============================] - 1s 198us/step - loss: 0.2140 - acc: 0.9382 - val_loss: 0.3700 - val_acc: 0.8950
# Epoch 10/300
# 3234/3234 [==============================] - 1s 202us/step - loss: 0.2122 - acc: 0.9385 - val_loss: 0.3914 - val_acc: 0.8923
# Epoch 11/300
# 3234/3234 [==============================] - 1s 190us/step - loss: 0.2126 - acc: 0.9391 - val_loss: 0.3782 - val_acc: 0.8978
# Epoch 12/300
# 3234/3234 [==============================] - 1s 198us/step - loss: 0.2124 - acc: 0.9375 - val_loss: 0.3865 - val_acc: 0.8950
# Epoch 13/300
# 3234/3234 [==============================] - 1s 174us/step - loss: 0.2104 - acc: 0.9378 - val_loss: 0.3689 - val_acc: 0.8978
# Epoch 14/300
# 3234/3234 [==============================] - 1s 190us/step - loss: 0.2102 - acc: 0.9385 - val_loss: 0.3694 - val_acc: 0.8978
# Epoch 15/300
# 3234/3234 [==============================] - 1s 197us/step - loss: 0.2156 - acc: 0.9391 - val_loss: 0.3740 - val_acc: 0.8950
# Epoch 16/300
# 3234/3234 [==============================] - 1s 190us/step - loss: 0.2136 - acc: 0.9363 - val_loss: 0.3765 - val_acc: 0.8950
# Epoch 17/300
# 3234/3234 [==============================] - 1s 198us/step - loss: 0.2159 - acc: 0.9378 - val_loss: 0.3912 - val_acc: 0.8950
# Epoch 18/300
# 3234/3234 [==============================] - 1s 199us/step - loss: 0.2142 - acc: 0.9354 - val_loss: 0.3862 - val_acc: 0.8950
# Epoch 19/300
# 3234/3234 [==============================] - 1s 194us/step - loss: 0.2127 - acc: 0.9385 - val_loss: 0.3675 - val_acc: 0.8950
# Epoch 20/300
# 3234/3234 [==============================] - 1s 197us/step - loss: 0.2144 - acc: 0.9378 - val_loss: 0.3779 - val_acc: 0.8978
# Epoch 21/300
# 3234/3234 [==============================] - 1s 197us/step - loss: 0.2153 - acc: 0.9375 - val_loss: 0.3752 - val_acc: 0.8950
# Epoch 22/300
# 3234/3234 [==============================] - 1s 196us/step - loss: 0.2120 - acc: 0.9394 - val_loss: 0.3852 - val_acc: 0.8950
# Epoch 23/300
# 3234/3234 [==============================] - 1s 197us/step - loss: 0.2115 - acc: 0.9366 - val_loss: 0.3783 - val_acc: 0.8950
# Epoch 24/300
# 3234/3234 [==============================] - 1s 196us/step - loss: 0.2169 - acc: 0.9363 - val_loss: 0.3746 - val_acc: 0.8978
# Epoch 25/300
# 3234/3234 [==============================] - 1s 196us/step - loss: 0.2143 - acc: 0.9382 - val_loss: 0.3630 - val_acc: 0.8895
# Epoch 26/300
# 3234/3234 [==============================] - 1s 193us/step - loss: 0.2147 - acc: 0.9357 - val_loss: 0.3685 - val_acc: 0.8950
# Epoch 27/300
# 3234/3234 [==============================] - 1s 184us/step - loss: 0.2134 - acc: 0.9363 - val_loss: 0.3892 - val_acc: 0.8978
# Epoch 28/300
# 3234/3234 [==============================] - 1s 164us/step - loss: 0.2129 - acc: 0.9378 - val_loss: 0.3927 - val_acc: 0.8978
# Epoch 29/300
# 3234/3234 [==============================] - 1s 182us/step - loss: 0.2168 - acc: 0.9385 - val_loss: 0.3863 - val_acc: 0.8978
# Epoch 30/300
# 3234/3234 [==============================] - 1s 191us/step - loss: 0.2127 - acc: 0.9372 - val_loss: 0.3831 - val_acc: 0.8950
# Epoch 31/300
# 3234/3234 [==============================] - 1s 179us/step - loss: 0.2125 - acc: 0.9394 - val_loss: 0.3851 - val_acc: 0.8950
# Epoch 32/300
# 3234/3234 [==============================] - 1s 192us/step - loss: 0.2103 - acc: 0.9369 - val_loss: 0.3710 - val_acc: 0.8978
# test accuracy:  0.8978
#
# TRAIN CONFUSION MATRIX
# Confusion matrix, without normalization
# [[ 206  105    4]
#  [  23 2604   10]
#  [   5   57  220]]
# Normalized confusion matrix
# [[0.65396825 0.33333333 0.01269841]
#  [0.00872203 0.98748578 0.00379219]
#  [0.0177305  0.20212766 0.78014184]]
# TEST CONFUSION MATRIX
# Confusion matrix, without normalization
# [[ 20  14   2]
#  [  2 284   8]
#  [  1  10  21]]
# Normalized confusion matrix
# [[0.55555556 0.38888889 0.05555556]
#  [0.00680272 0.96598639 0.02721088]
#  [0.03125    0.3125     0.65625   ]]
# Wall time: 24.2 s

# %% [markdown]
# #### 3 word, 3 char

# %%
# %%time
categories_count = CATEGORIES_COUNT

X_train = X_train_3_3
X_test = X_test_3_3

meta_net = Sequential()
meta_net.add(Dense(512, input_shape=X_train[0].shape))
meta_net.add(Dropout(0.5))
meta_net.add(Dense(256))
meta_net.add(Dropout(0.5))
meta_net.add(Dense(categories_count, activation='softmax'))
meta_net.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
print(meta_net.summary())
    
callback = keras.callbacks.EarlyStopping(monitor='val_loss', min_delta=0, patience=7, verbose=0, mode='auto')
history_callback = meta_net.fit(X_train, y_train, validation_data=(X_test, y_test), 
                                epochs=300, batch_size=100, callbacks=[callback])

test_scores = meta_net.evaluate(X_test, y_test, verbose=0)
    
print("test accuracy:  %.4f" % test_scores[1])
print("")

y_train_pred = (meta_net.predict(X_train).round()).argmax(axis=1)
y_test_pred = (meta_net.predict(X_test).round()).argmax(axis=1)

print("TRAIN CONFUSION MATRIX")
print_confusion_matrix(X_train, (y_train.round()).argmax(axis=1), y_train_pred, categories_count=CATEGORIES_COUNT)

print("")
print("TEST CONFUSION MATRIX")
print_confusion_matrix(X_test, (y_test.round()).argmax(axis=1), y_test_pred, categories_count=CATEGORIES_COUNT)

# and than write results info files
file_path_train = "./Stacking_Results_France_ByShape/meta_net_train_3_3.npy"
file_path_test = "./Stacking_Results_France_ByShape/meta_net_test_3_3.npy"

np.save(file_path_train, y_train_pred)
np.save(file_path_test, y_test_pred)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_7 (Dense)              (None, 512)               3584
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_8 (Dense)              (None, 256)               131328
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_9 (Dense)              (None, 3)                 771
# =================================================================
# Total params: 135,683
# Trainable params: 135,683
# Non-trainable params: 0
# _________________________________________________________________
# None
# Train on 3234 samples, validate on 362 samples
# Epoch 1/300
# 3234/3234 [==============================] - 2s 483us/step - loss: 0.3364 - acc: 0.8788 - val_loss: 0.5370 - val_acc: 0.8619
# Epoch 2/300
# 3234/3234 [==============================] - 1s 202us/step - loss: 0.2046 - acc: 0.9453 - val_loss: 0.5353 - val_acc: 0.8619
# Epoch 3/300
# 3234/3234 [==============================] - 1s 198us/step - loss: 0.1987 - acc: 0.9459 - val_loss: 0.5087 - val_acc: 0.8619
# Epoch 4/300
# 3234/3234 [==============================] - 1s 200us/step - loss: 0.2017 - acc: 0.9447 - val_loss: 0.5221 - val_acc: 0.8619
# Epoch 5/300
# 3234/3234 [==============================] - 1s 201us/step - loss: 0.1971 - acc: 0.9453 - val_loss: 0.5149 - val_acc: 0.8591
# Epoch 6/300
# 3234/3234 [==============================] - 1s 189us/step - loss: 0.1993 - acc: 0.9437 - val_loss: 0.5241 - val_acc: 0.8619
# Epoch 7/300
# 3234/3234 [==============================] - 1s 202us/step - loss: 0.2002 - acc: 0.9447 - val_loss: 0.5075 - val_acc: 0.8646
# Epoch 8/300
# 3234/3234 [==============================] - 1s 197us/step - loss: 0.2015 - acc: 0.9456 - val_loss: 0.5179 - val_acc: 0.8619
# Epoch 9/300
# 3234/3234 [==============================] - 1s 192us/step - loss: 0.2009 - acc: 0.9477 - val_loss: 0.5260 - val_acc: 0.8619
# Epoch 10/300
# 3234/3234 [==============================] - 1s 189us/step - loss: 0.1986 - acc: 0.9447 - val_loss: 0.5137 - val_acc: 0.8619
# Epoch 11/300
# 3234/3234 [==============================] - 1s 197us/step - loss: 0.2002 - acc: 0.9437 - val_loss: 0.5043 - val_acc: 0.8646
# Epoch 12/300
# 3234/3234 [==============================] - 1s 199us/step - loss: 0.2028 - acc: 0.9450 - val_loss: 0.4817 - val_acc: 0.8646
# Epoch 13/300
# 3234/3234 [==============================] - 1s 184us/step - loss: 0.1961 - acc: 0.9447 - val_loss: 0.5261 - val_acc: 0.8646
# Epoch 14/300
# 3234/3234 [==============================] - 1s 195us/step - loss: 0.2022 - acc: 0.9447 - val_loss: 0.5151 - val_acc: 0.8619
# Epoch 15/300
# 3234/3234 [==============================] - 1s 207us/step - loss: 0.1989 - acc: 0.9450 - val_loss: 0.5275 - val_acc: 0.8619
# Epoch 16/300
# 3234/3234 [==============================] - 1s 201us/step - loss: 0.2023 - acc: 0.9434 - val_loss: 0.5210 - val_acc: 0.8646
# Epoch 17/300
# 3234/3234 [==============================] - 1s 200us/step - loss: 0.2026 - acc: 0.9440 - val_loss: 0.5183 - val_acc: 0.8646
# Epoch 18/300
# 3234/3234 [==============================] - 1s 198us/step - loss: 0.2003 - acc: 0.9437 - val_loss: 0.5121 - val_acc: 0.8674
# Epoch 19/300
# 3234/3234 [==============================] - 1s 193us/step - loss: 0.1995 - acc: 0.9425 - val_loss: 0.5111 - val_acc: 0.8674
# test accuracy:  0.8674
#
# TRAIN CONFUSION MATRIX
# Confusion matrix, without normalization
# [[ 218   93    4]
#  [  14 2605   18]
#  [   5   42  235]]
# Normalized confusion matrix
# [[0.69206349 0.2952381  0.01269841]
#  [0.00530906 0.987865   0.00682594]
#  [0.0177305  0.14893617 0.83333333]]
# TEST CONFUSION MATRIX
# Confusion matrix, without normalization
# [[ 19  14   3]
#  [  3 275  16]
#  [  1  12  19]]
# Normalized confusion matrix
# [[0.52777778 0.38888889 0.08333333]
#  [0.01020408 0.93537415 0.05442177]
#  [0.03125    0.375      0.59375   ]]
# Wall time: 16.4 s

# %% [markdown]
# #### 3 word, 4 char

# %%
# %%time
categories_count = CATEGORIES_COUNT

X_train = X_train_3_4
X_test = X_test_3_4

meta_net = Sequential()
meta_net.add(Dense(512, input_shape=X_train[0].shape))
meta_net.add(Dropout(0.5))
meta_net.add(Dense(256))
meta_net.add(Dropout(0.5))
meta_net.add(Dense(categories_count, activation='softmax'))
meta_net.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
print(meta_net.summary())
    
callback = keras.callbacks.EarlyStopping(monitor='val_loss', min_delta=0, patience=7, verbose=0, mode='auto')
history_callback = meta_net.fit(X_train, y_train, validation_data=(X_test, y_test), 
                                epochs=300, batch_size=100, callbacks=[callback])

test_scores = meta_net.evaluate(X_test, y_test, verbose=0)
    
print("test accuracy:  %.4f" % test_scores[1])
print("")

y_train_pred = (meta_net.predict(X_train).round()).argmax(axis=1)
y_test_pred = (meta_net.predict(X_test).round()).argmax(axis=1)

print("TRAIN CONFUSION MATRIX")
print_confusion_matrix(X_train, (y_train.round()).argmax(axis=1), y_train_pred, categories_count=CATEGORIES_COUNT)

print("")
print("TEST CONFUSION MATRIX")
print_confusion_matrix(X_test, (y_test.round()).argmax(axis=1), y_test_pred, categories_count=CATEGORIES_COUNT)

# and than write results info files
file_path_train = "./Stacking_Results_France_ByShape/meta_net_train_3_4.npy"
file_path_test = "./Stacking_Results_France_ByShape/meta_net_test_3_4.npy"

np.save(file_path_train, y_train_pred)
np.save(file_path_test, y_test_pred)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_10 (Dense)             (None, 512)               3584
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_11 (Dense)             (None, 256)               131328
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_12 (Dense)             (None, 3)                 771
# =================================================================
# Total params: 135,683
# Trainable params: 135,683
# Non-trainable params: 0
# _________________________________________________________________
# None
# Train on 3234 samples, validate on 362 samples
# Epoch 1/300
# 3234/3234 [==============================] - 2s 487us/step - loss: 0.3367 - acc: 0.8831 - val_loss: 0.5460 - val_acc: 0.8591
# Epoch 2/300
# 3234/3234 [==============================] - 1s 182us/step - loss: 0.2042 - acc: 0.9440 - val_loss: 0.5394 - val_acc: 0.8619
# Epoch 3/300
# 3234/3234 [==============================] - 1s 195us/step - loss: 0.1991 - acc: 0.9447 - val_loss: 0.5245 - val_acc: 0.8619
# Epoch 4/300
# 3234/3234 [==============================] - 1s 200us/step - loss: 0.2018 - acc: 0.9447 - val_loss: 0.5090 - val_acc: 0.8619
# Epoch 5/300
# 3234/3234 [==============================] - 1s 194us/step - loss: 0.1988 - acc: 0.9443 - val_loss: 0.5265 - val_acc: 0.8619
# Epoch 6/300
# 3234/3234 [==============================] - 1s 196us/step - loss: 0.1978 - acc: 0.9422 - val_loss: 0.5026 - val_acc: 0.8619
# Epoch 7/300
# 3234/3234 [==============================] - 1s 197us/step - loss: 0.1958 - acc: 0.9443 - val_loss: 0.5050 - val_acc: 0.8646
# Epoch 8/300
# 3234/3234 [==============================] - 1s 199us/step - loss: 0.1971 - acc: 0.9437 - val_loss: 0.5138 - val_acc: 0.8646
# Epoch 9/300
# 3234/3234 [==============================] - 1s 200us/step - loss: 0.2012 - acc: 0.9428 - val_loss: 0.5083 - val_acc: 0.8619
# Epoch 10/300
# 3234/3234 [==============================] - 1s 190us/step - loss: 0.2032 - acc: 0.9434 - val_loss: 0.4982 - val_acc: 0.8619
# Epoch 11/300
# 3234/3234 [==============================] - 1s 202us/step - loss: 0.1961 - acc: 0.9437 - val_loss: 0.5097 - val_acc: 0.8619
# Epoch 12/300
# 3234/3234 [==============================] - 1s 198us/step - loss: 0.1992 - acc: 0.9440 - val_loss: 0.5032 - val_acc: 0.8646
# Epoch 13/300
# 3234/3234 [==============================] - 1s 198us/step - loss: 0.2045 - acc: 0.9422 - val_loss: 0.5160 - val_acc: 0.8646
# Epoch 14/300
# 3234/3234 [==============================] - 1s 186us/step - loss: 0.1981 - acc: 0.9428 - val_loss: 0.5086 - val_acc: 0.8674
# Epoch 15/300
# 3234/3234 [==============================] - 1s 204us/step - loss: 0.1973 - acc: 0.9428 - val_loss: 0.5199 - val_acc: 0.8646
# Epoch 16/300
# 3234/3234 [==============================] - 1s 197us/step - loss: 0.1950 - acc: 0.9447 - val_loss: 0.5090 - val_acc: 0.8674
# Epoch 17/300
# 3234/3234 [==============================] - 1s 202us/step - loss: 0.1981 - acc: 0.9440 - val_loss: 0.5117 - val_acc: 0.8619
# test accuracy:  0.8619
#
# TRAIN CONFUSION MATRIX
# Confusion matrix, without normalization
# [[ 217   93    5]
#  [  13 2610   14]
#  [   4   49  229]]
# Normalized confusion matrix
# [[0.68888889 0.2952381  0.01587302]
#  [0.00492984 0.98976109 0.00530906]
#  [0.0141844  0.17375887 0.81205674]]
# TEST CONFUSION MATRIX
# Confusion matrix, without normalization
# [[ 20  13   3]
#  [  3 274  17]
#  [  1  12  19]]
# Normalized confusion matrix
# [[0.55555556 0.36111111 0.08333333]
#  [0.01020408 0.93197279 0.05782313]
#  [0.03125    0.375      0.59375   ]]
# Wall time: 14.9 s

# %% [markdown]
# #### 4 word, 3 char

# %%
# %%time
categories_count = CATEGORIES_COUNT

X_train = X_train_4_3
X_test = X_test_4_3

meta_net = Sequential()
meta_net.add(Dense(512, input_shape=X_train[0].shape))
meta_net.add(Dropout(0.5))
meta_net.add(Dense(256))
meta_net.add(Dropout(0.5))
meta_net.add(Dense(categories_count, activation='softmax'))
meta_net.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
print(meta_net.summary())
    
callback = keras.callbacks.EarlyStopping(monitor='val_loss', min_delta=0, patience=7, verbose=0, mode='auto')
history_callback = meta_net.fit(X_train, y_train, validation_data=(X_test, y_test), 
                                epochs=300, batch_size=100, callbacks=[callback])

test_scores = meta_net.evaluate(X_test, y_test, verbose=0)
    
print("test accuracy:  %.4f" % test_scores[1])
print("")

y_train_pred = (meta_net.predict(X_train).round()).argmax(axis=1)
y_test_pred = (meta_net.predict(X_test).round()).argmax(axis=1)

print("TRAIN CONFUSION MATRIX")
print_confusion_matrix(X_train, (y_train.round()).argmax(axis=1), y_train_pred, categories_count=CATEGORIES_COUNT)

print("")
print("TEST CONFUSION MATRIX")
print_confusion_matrix(X_test, (y_test.round()).argmax(axis=1), y_test_pred, categories_count=CATEGORIES_COUNT)

# and than write results info files
file_path_train = "./Stacking_Results_France_ByShape/meta_net_train_4_3.npy"
file_path_test = "./Stacking_Results_France_ByShape/meta_net_test_4_3.npy"

np.save(file_path_train, y_train_pred)
np.save(file_path_test, y_test_pred)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_13 (Dense)             (None, 512)               3584
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_14 (Dense)             (None, 256)               131328
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_15 (Dense)             (None, 3)                 771
# =================================================================
# Total params: 135,683
# Trainable params: 135,683
# Non-trainable params: 0
# _________________________________________________________________
# None
# Train on 3234 samples, validate on 362 samples
# Epoch 1/300
# 3234/3234 [==============================] - 2s 564us/step - loss: 0.3435 - acc: 0.8856 - val_loss: 0.4052 - val_acc: 0.8702
# Epoch 2/300
# 3234/3234 [==============================] - 1s 191us/step - loss: 0.2195 - acc: 0.9382 - val_loss: 0.4101 - val_acc: 0.8729
# Epoch 3/300
# 3234/3234 [==============================] - 1s 182us/step - loss: 0.2100 - acc: 0.9400 - val_loss: 0.4160 - val_acc: 0.8757
# Epoch 4/300
# 3234/3234 [==============================] - 1s 196us/step - loss: 0.2163 - acc: 0.9385 - val_loss: 0.4023 - val_acc: 0.8702
# Epoch 5/300
# 3234/3234 [==============================] - 1s 205us/step - loss: 0.2109 - acc: 0.9385 - val_loss: 0.4064 - val_acc: 0.8757
# Epoch 6/300
# 3234/3234 [==============================] - 1s 201us/step - loss: 0.2134 - acc: 0.9382 - val_loss: 0.4100 - val_acc: 0.8729
# Epoch 7/300
# 3234/3234 [==============================] - 1s 187us/step - loss: 0.2153 - acc: 0.9375 - val_loss: 0.4005 - val_acc: 0.8729
# Epoch 8/300
# 3234/3234 [==============================] - 1s 184us/step - loss: 0.2165 - acc: 0.9354 - val_loss: 0.4075 - val_acc: 0.8757
# Epoch 9/300
# 3234/3234 [==============================] - 1s 181us/step - loss: 0.2119 - acc: 0.9363 - val_loss: 0.4104 - val_acc: 0.8757
# Epoch 10/300
# 3234/3234 [==============================] - 1s 195us/step - loss: 0.2202 - acc: 0.9385 - val_loss: 0.4062 - val_acc: 0.8729
# Epoch 11/300
# 3234/3234 [==============================] - 1s 196us/step - loss: 0.2142 - acc: 0.9378 - val_loss: 0.4277 - val_acc: 0.8757
# Epoch 12/300
# 3234/3234 [==============================] - 1s 195us/step - loss: 0.2125 - acc: 0.9375 - val_loss: 0.4018 - val_acc: 0.8757
# Epoch 13/300
# 3234/3234 [==============================] - 1s 196us/step - loss: 0.2176 - acc: 0.9378 - val_loss: 0.3983 - val_acc: 0.8729
# Epoch 14/300
# 3234/3234 [==============================] - 1s 203us/step - loss: 0.2117 - acc: 0.9397 - val_loss: 0.4139 - val_acc: 0.8729
# Epoch 15/300
# 3234/3234 [==============================] - 1s 197us/step - loss: 0.2169 - acc: 0.9363 - val_loss: 0.4118 - val_acc: 0.8757
# Epoch 16/300
# 3234/3234 [==============================] - 1s 196us/step - loss: 0.2184 - acc: 0.9348 - val_loss: 0.4033 - val_acc: 0.8729
# Epoch 17/300
# 3234/3234 [==============================] - 1s 199us/step - loss: 0.2150 - acc: 0.9388 - val_loss: 0.4097 - val_acc: 0.8674
# Epoch 18/300
# 3234/3234 [==============================] - 1s 199us/step - loss: 0.2142 - acc: 0.9375 - val_loss: 0.4138 - val_acc: 0.8729
# Epoch 19/300
# 3234/3234 [==============================] - 1s 178us/step - loss: 0.2145 - acc: 0.9388 - val_loss: 0.4012 - val_acc: 0.8785
# Epoch 20/300
# 3234/3234 [==============================] - 1s 189us/step - loss: 0.2185 - acc: 0.9375 - val_loss: 0.4074 - val_acc: 0.8729
# test accuracy:  0.8729
#
# TRAIN CONFUSION MATRIX
# Confusion matrix, without normalization
# [[ 214   97    4]
#  [  25 2587   25]
#  [   1   51  230]]
# Normalized confusion matrix
# [[0.67936508 0.30793651 0.01269841]
#  [0.00948047 0.98103906 0.00948047]
#  [0.0035461  0.18085106 0.81560284]]
# TEST CONFUSION MATRIX
# Confusion matrix, without normalization
# [[ 18  12   6]
#  [  4 279  11]
#  [  1  12  19]]
# Normalized confusion matrix
# [[0.5        0.33333333 0.16666667]
#  [0.01360544 0.94897959 0.03741497]
#  [0.03125    0.375      0.59375   ]]
# Wall time: 17.1 s

# %% [markdown]
# #### 4 word, 4 char

# %%
# %%time
categories_count = CATEGORIES_COUNT

X_train = X_train_4_4
X_test = X_test_4_4

meta_net = Sequential()
meta_net.add(Dense(512, input_shape=X_train[0].shape))
meta_net.add(Dropout(0.5))
meta_net.add(Dense(256))
meta_net.add(Dropout(0.5))
meta_net.add(Dense(categories_count, activation='softmax'))
meta_net.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
print(meta_net.summary())
    
callback = keras.callbacks.EarlyStopping(monitor='val_loss', min_delta=0, patience=7, verbose=0, mode='auto')
history_callback = meta_net.fit(X_train, y_train, validation_data=(X_test, y_test), 
                                epochs=300, batch_size=100, callbacks=[callback])

test_scores = meta_net.evaluate(X_test, y_test, verbose=0)
    
print("test accuracy:  %.4f" % test_scores[1])
print("")

y_train_pred = (meta_net.predict(X_train).round()).argmax(axis=1)
y_test_pred = (meta_net.predict(X_test).round()).argmax(axis=1)

print("TRAIN CONFUSION MATRIX")
print_confusion_matrix(X_train, (y_train.round()).argmax(axis=1), y_train_pred, categories_count=CATEGORIES_COUNT)

print("")
print("TEST CONFUSION MATRIX")
print_confusion_matrix(X_test, (y_test.round()).argmax(axis=1), y_test_pred, categories_count=CATEGORIES_COUNT)

# and than write results info files
file_path_train = "./Stacking_Results_France_ByShape/meta_net_train_4_4.npy"
file_path_test = "./Stacking_Results_France_ByShape/meta_net_test_4_4.npy"

np.save(file_path_train, y_train_pred)
np.save(file_path_test, y_test_pred)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_16 (Dense)             (None, 512)               3584
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_17 (Dense)             (None, 256)               131328
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_18 (Dense)             (None, 3)                 771
# =================================================================
# Total params: 135,683
# Trainable params: 135,683
# Non-trainable params: 0
# _________________________________________________________________
# None
# Train on 3234 samples, validate on 362 samples
# Epoch 1/300
# 3234/3234 [==============================] - 2s 561us/step - loss: 0.3481 - acc: 0.8887 - val_loss: 0.3995 - val_acc: 0.8757
# Epoch 2/300
# 3234/3234 [==============================] - 1s 190us/step - loss: 0.2259 - acc: 0.9385 - val_loss: 0.4079 - val_acc: 0.8757
# Epoch 3/300
# 3234/3234 [==============================] - 1s 193us/step - loss: 0.2200 - acc: 0.9357 - val_loss: 0.3995 - val_acc: 0.8757
# Epoch 4/300
# 3234/3234 [==============================] - 1s 206us/step - loss: 0.2136 - acc: 0.9388 - val_loss: 0.4033 - val_acc: 0.8785
# Epoch 5/300
# 3234/3234 [==============================] - 1s 200us/step - loss: 0.2173 - acc: 0.9391 - val_loss: 0.3965 - val_acc: 0.8867
# Epoch 6/300
# 3234/3234 [==============================] - 1s 196us/step - loss: 0.2171 - acc: 0.9403 - val_loss: 0.3985 - val_acc: 0.8812
# Epoch 7/300
# 3234/3234 [==============================] - 1s 198us/step - loss: 0.2088 - acc: 0.9388 - val_loss: 0.4169 - val_acc: 0.8785
# Epoch 8/300
# 3234/3234 [==============================] - 1s 201us/step - loss: 0.2211 - acc: 0.9400 - val_loss: 0.3962 - val_acc: 0.8867
# Epoch 9/300
# 3234/3234 [==============================] - 1s 199us/step - loss: 0.2156 - acc: 0.9378 - val_loss: 0.4021 - val_acc: 0.8812
# Epoch 10/300
# 3234/3234 [==============================] - 1s 197us/step - loss: 0.2177 - acc: 0.9375 - val_loss: 0.4155 - val_acc: 0.8785
# Epoch 11/300
# 3234/3234 [==============================] - 1s 204us/step - loss: 0.2181 - acc: 0.9375 - val_loss: 0.3962 - val_acc: 0.8840
# Epoch 12/300
# 3234/3234 [==============================] - 1s 197us/step - loss: 0.2134 - acc: 0.9394 - val_loss: 0.4010 - val_acc: 0.8785
# Epoch 13/300
# 3234/3234 [==============================] - 1s 199us/step - loss: 0.2094 - acc: 0.9391 - val_loss: 0.4128 - val_acc: 0.8785
# Epoch 14/300
# 3234/3234 [==============================] - 1s 204us/step - loss: 0.2168 - acc: 0.9382 - val_loss: 0.3995 - val_acc: 0.8812
# Epoch 15/300
# 3234/3234 [==============================] - 1s 201us/step - loss: 0.2109 - acc: 0.9394 - val_loss: 0.4075 - val_acc: 0.8812
# test accuracy:  0.8812
#
# TRAIN CONFUSION MATRIX
# Confusion matrix, without normalization
# [[ 220   91    4]
#  [  32 2578   27]
#  [   1   46  235]]
# Normalized confusion matrix
# [[0.6984127  0.28888889 0.01269841]
#  [0.012135   0.97762609 0.01023891]
#  [0.0035461  0.16312057 0.83333333]]
# TEST CONFUSION MATRIX
# Confusion matrix, without normalization
# [[ 19  11   6]
#  [  4 278  12]
#  [  2   8  22]]
# Normalized confusion matrix
# [[0.52777778 0.30555556 0.16666667]
#  [0.01360544 0.94557823 0.04081633]
#  [0.0625     0.25       0.6875    ]]
# Wall time: 14.3 s
