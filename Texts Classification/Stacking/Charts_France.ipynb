# %%
import numpy as np
import math
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
Shape_Wiki_knn_u = [0.8895, 0.8950, 0.8674, 0.8591, 0.8757, 0.8757]
Shape_Wiki_knn_d = [0.8867, 0.8867, 0.8591, 0.8591, 0.8674, 0.8840]
Shape_Wiki_svm = [0.8895, 0.8867, 0.8619, 0.8619, 0.8702, 0.8702]
Shape_Wiki_net = [0.8895, 0.8978, 0.8674, 0.8619, 0.8729, 0.8812]

Shape_Glove_knn_u = [0.8950, 0.8950, 0.8702, 0.8591, 0.8702, 0.8702]
Shape_Glove_knn_d = [0.8923, 0.8867, 0.8619, 0.8702, 0.8729, 0.8785]
Shape_Glove_svm = [0.8867, 0.8840, 0.8591, 0.8481, 0.8674, 0.8674]
Shape_Glove_net = [0.8923, 0.9061, 0.8674, 0.8691, 0.8702, 0.8867]

Meaning_Wiki_knn_u = [0.9432, 0.9403, 0.9602, 0.9602, 0.9375, 0.9432]
Meaning_Wiki_knn_d = [0.9403, 0.9375, 0.9602, 0.9602, 0.9375, 0.9403]
Meaning_Wiki_svm = [0.9432, 0.9460, 0.9631, 0.9631, 0.9432, 0.9460]
Meaning_Wiki_net = [0.9460, 0.9347, 0.9574, 0.9602, 0.9545, 0.9432]

Meaning_Glove_knn_u = [0.9432, 0.9290, 0.9602, 0.9602, 0.9489, 0.9347]
Meaning_Glove_knn_d = [0.9403, 0.9375, 0.9602, 0.9602, 0.9489, 0.9318]
Meaning_Glove_svm = [0.9403, 0.9375, 0.9631, 0.9602, 0.9432, 0.9432]
Meaning_Glove_net = [0.9432, 0.9233, 0.9659, 0.9545, 0.9602, 0.9375]

Large_Wiki_knn_u = [0.6807, 0.6687, 0.6687, 0.6566, 0.6747, 0.6627]
Large_Wiki_knn_d = [0.6657, 0.6325, 0.6446, 0.6265, 0.6627, 0.6295]
Large_Wiki_svm = [0.6928, 0.6898, 0.6958, 0.7018, 0.7018, 0.7139]
Large_Wiki_net = [0.7078, 0.6958, 0.6988, 0.6747, 0.6928, 0.7018]

Large_Glove_knn_u = [0.7982, 0.7651, 0.8042, 0.7620, 0.8012, 0.7651]
Large_Glove_knn_d = [0.7741, 0.7440, 0.7861, 0.7620, 0.7771, 0.7380]
Large_Glove_svm = [0.7952, 0.7741, 0.7952, 0.7741, 0.7952, 0.7741]
Large_Glove_net = [0.7952, 0.7681, 0.7952, 0.7711, 0.7982, 0.7741]

# %%
plt.figure(figsize=(10, 6))

plt.plot(['2_3', '2_4', '3_3', '3_4', '4_3', '4_4'], Shape_Wiki_knn_u)
plt.plot(['2_3', '2_4', '3_3', '3_4', '4_3', '4_4'], Shape_Wiki_knn_d)
plt.plot(['2_3', '2_4', '3_3', '3_4', '4_3', '4_4'], Shape_Wiki_svm)
plt.plot(['2_3', '2_4', '3_3', '3_4', '4_3', '4_4'], Shape_Wiki_net)

plt.plot(['2_3', '2_4', '3_3', '3_4', '4_3', '4_4'], Shape_Glove_knn_u)
plt.plot(['2_3', '2_4', '3_3', '3_4', '4_3', '4_4'], Shape_Glove_knn_d)
plt.plot(['2_3', '2_4', '3_3', '3_4', '4_3', '4_4'], Shape_Glove_svm)
plt.plot(['2_3', '2_4', '3_3', '3_4', '4_3', '4_4'], Shape_Glove_net)

# %%
plt.figure(figsize=(10, 6))

plt.plot(['2_3', '2_4', '3_3', '3_4', '4_3', '4_4'], Meaning_Wiki_knn_u)
plt.plot(['2_3', '2_4', '3_3', '3_4', '4_3', '4_4'], Meaning_Wiki_knn_d)
plt.plot(['2_3', '2_4', '3_3', '3_4', '4_3', '4_4'], Meaning_Wiki_svm)
plt.plot(['2_3', '2_4', '3_3', '3_4', '4_3', '4_4'], Meaning_Wiki_net)

plt.plot(['2_3', '2_4', '3_3', '3_4', '4_3', '4_4'], Meaning_Glove_knn_u)
plt.plot(['2_3', '2_4', '3_3', '3_4', '4_3', '4_4'], Meaning_Glove_knn_d)
plt.plot(['2_3', '2_4', '3_3', '3_4', '4_3', '4_4'], Meaning_Glove_svm)
plt.plot(['2_3', '2_4', '3_3', '3_4', '4_3', '4_4'], Meaning_Glove_net)

# %%
plt.figure(figsize=(10, 6))

plt.plot(['2_3', '2_4', '3_3', '3_4', '4_3', '4_4'], Large_Wiki_knn_u)
plt.plot(['2_3', '2_4', '3_3', '3_4', '4_3', '4_4'], Large_Wiki_knn_d)
plt.plot(['2_3', '2_4', '3_3', '3_4', '4_3', '4_4'], Large_Wiki_svm)
plt.plot(['2_3', '2_4', '3_3', '3_4', '4_3', '4_4'], Large_Wiki_net)

# %%
plt.figure(figsize=(10, 6))

plt.plot(['2_3', '2_4', '3_3', '3_4', '4_3', '4_4'], Large_Glove_knn_u)
plt.plot(['2_3', '2_4', '3_3', '3_4', '4_3', '4_4'], Large_Glove_knn_d)
plt.plot(['2_3', '2_4', '3_3', '3_4', '4_3', '4_4'], Large_Glove_svm)
plt.plot(['2_3', '2_4', '3_3', '3_4', '4_3', '4_4'], Large_Glove_net)

# %% [markdown]
# ### 2_4 or 3_3 ??

# %%
all_arrays = np.array([Shape_Wiki_knn_u, Shape_Wiki_knn_d, Shape_Wiki_svm, Shape_Wiki_net, 
             Shape_Glove_knn_u, Shape_Glove_knn_d, Shape_Glove_svm, Shape_Glove_net,
             Meaning_Wiki_knn_u, Meaning_Wiki_knn_d, Meaning_Wiki_svm, Meaning_Wiki_svm,
             Meaning_Glove_knn_u, Meaning_Glove_knn_d, Meaning_Glove_svm, Meaning_Glove_net,
             Large_Wiki_knn_u, Large_Wiki_knn_d, Large_Wiki_svm, Large_Wiki_net,
             Large_Glove_knn_u, Large_Glove_knn_d, Large_Glove_svm, Large_Glove_net])

# %%
all_arrays.shape
# Out:
# (24, 6)

# %%
mean_acc_for_each_pair_of_nets = np.sum(all_arrays, axis=0, dtype=np.float64) / 24
print(mean_acc_for_each_pair_of_nets)
# Out:
# [0.85700417 0.84888333 0.854125   0.84579167 0.85138333 0.84565833]

# %%
plt.figure(figsize=(10, 6))

plt.plot(['2_3', '2_4', '3_3', '3_4', '4_3', '4_4'], mean_acc_for_each_pair_of_nets)

# %% [markdown]
# #### The worst variants are 3_4 and 4_4.
# 2_4 is averagely also not so good. But it was the best in "ByShape" classification.
# 2_3 seems to be averagely the best one. Than 3_3 is also good.

# %% [markdown]
# ### Let's find the best meta-classifier

# %%
mean_acc_for_each_clf_and_dataset = np.sum(all_arrays, axis=1, dtype=np.float64) / 6
print(mean_acc_for_each_clf_and_dataset)
# Out:
# [0.87706667 0.87383333 0.8734     0.87845    0.87661667 0.87708333
#  0.86878333 0.88196667 0.94743333 0.946      0.95076667 0.95076667
#  0.94603333 0.94648333 0.94791667 0.94743333 0.66868333 0.64358333
#  0.69931667 0.69528333 0.78263333 0.76355    0.78465    0.78365   ]

# %%
mean_acc_knn_u = mean_acc_for_each_clf_and_dataset[0] + mean_acc_for_each_clf_and_dataset[4] \
    + mean_acc_for_each_clf_and_dataset[8] + mean_acc_for_each_clf_and_dataset[12] + mean_acc_for_each_clf_and_dataset[16] \
    + mean_acc_for_each_clf_and_dataset[20]
mean_acc_knn_d = mean_acc_for_each_clf_and_dataset[1] + mean_acc_for_each_clf_and_dataset[5] \
    + mean_acc_for_each_clf_and_dataset[9] + mean_acc_for_each_clf_and_dataset[13] + mean_acc_for_each_clf_and_dataset[17] \
    + mean_acc_for_each_clf_and_dataset[21]
mean_acc_svm = mean_acc_for_each_clf_and_dataset[2] + mean_acc_for_each_clf_and_dataset[6] \
    + mean_acc_for_each_clf_and_dataset[10] + mean_acc_for_each_clf_and_dataset[14] + mean_acc_for_each_clf_and_dataset[18] \
    + mean_acc_for_each_clf_and_dataset[22]
mean_acc_net = mean_acc_for_each_clf_and_dataset[3] + mean_acc_for_each_clf_and_dataset[7] \
    + mean_acc_for_each_clf_and_dataset[11] + mean_acc_for_each_clf_and_dataset[15] + mean_acc_for_each_clf_and_dataset[19] \
    + mean_acc_for_each_clf_and_dataset[23]

# %%
mean_acc_clfs = np.array([mean_acc_knn_u, mean_acc_knn_d, mean_acc_svm, mean_acc_net]) / 6
print(mean_acc_clfs)
# Out:
# [0.84974444 0.84175556 0.85413889 0.85625833]

# %%
plt.figure(figsize=(10, 6))

plt.plot(['knn_uniform', 'knn_distance', 'svm', 'meta_net'], mean_acc_clfs)
